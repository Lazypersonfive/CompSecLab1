# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import OpenAttack
import numpy as np
import datasets
from textblob import TextBlob

class MyClassifier(OpenAttack.Classifier):
    def get_pred(self, input_):
        return self.get_prob(input_).argmax(axis=1)

    def get_prob(self, input_):
        ret = []
        for sent in input_:
            text_blob = TextBlob(sent)
            polarity = text_blob.sentiment.polarity

            if polarity > 0:
                ret.append(np.array([0, 1]))
            else:
                ret.append(np.array([1, 0]))

        return np.array(ret)

def dataset_mapping(x):
    return {
        "x": x["sentence"],
        # "y": 1 if x["label"] > 0.5 else 0,
        "y": x["label"],
    }

def main():
    # 从 datasets 库中加载 IMDB 数据集的前 1000 个样本
    imdb_train = datasets.load_dataset("sst", split="train[:10]").map(function=dataset_mapping)

    # 使用自定义分类器作为受害者模型
    victim = MyClassifier()

    # 选择 DWB 作为攻击者并使用默认参数初始化
    attacker = OpenAttack.attackers.PWWSAttacker()  # 修改此行

    # 准备进行攻击
    attack_eval = OpenAttack.AttackEval(attacker, victim, metrics = [
        OpenAttack.metric.SemanticSimilarity(),
        OpenAttack.metric.GrammaticalErrors(),
        # OpenAttack.metric.Fluency()
        # OpenAttack.metric.EditDistance(),
        # OpenAttack.metric.ModificationRate(),
    ])

    # 发起攻击并打印攻击结果
    attack_eval.eval(imdb_train, visualize=True)

if __name__ == "__main__":
    main()
# Out:
# WARNING:datasets.builder:No config specified, defaulting to: sst/default
# WARNING:datasets.builder:Found cached dataset sst (/root/.cache/huggingface/datasets/sst/default/1.0.0/b8a7889ef01c5d3ae8c379b84cc4080f8aad3ac2bc538701cbe0ac6416fb76ff)
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/sst/default/1.0.0/b8a7889ef01c5d3ae8c379b84cc4080f8aad3ac2bc538701cbe0ac6416fb76ff/cache-114503b74b29a34f.arrow
# /usr/local/lib/python3.9/dist-packages/nltk/corpus/reader/wordnet.py:1183: UserWarning: The multilingual functions are not available with this Wordnet version
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# it ' s the work of an artist , one whose    | Victim Model Queries:    221
#                                             | Semantic Similarity:     0.9866516
# view of America , history and the           | Grammatical Errors:      8
# view of america , history and the           | Succeed:                 yes
#                                             |
# awkwardness of human life is generous and   |
# awkwardness of human life is generous and   |
#                                             |
# deep .                                      |
# deep .                                      |
#                                             |
# Sample: 525 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             |
# Though it ' s not very well shot or         |
# though it ' s not very well shot or         |
#                                             |
# composed or edited , the score is too       | Running Time:            0.0064371
# composed or edited , the score is too       | Query Exceeded:          no
#                                             | Victim Model Queries:    151
# insistent and the dialogue is frequently    | Semantic Similarity:     0.9713243
# insistent and the dialogue is frequently    | Grammatical Errors:      6
#                                             | Succeed:                 yes
# overwrought and crudely literal , the film  |
# overwrought and crudely genuine , the film  |
#                                             |
# shatters you in waves .                     |
# shatters you in waves .                     |
#                                             |
# Sample: 526 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             | Running Time:            0.0067084
# The entire cast is extraordinarily good     | Query Exceeded:          no
# the entire cast is extraordinarily serious  | Victim Model Queries:    60
#                                             | Semantic Similarity:     0.8462119
# .                                           | Grammatical Errors:      2
# .                                           | Succeed:                 yes
#                                             |
# Sample: 527 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0057278
# Yakusho , as always , is wonderful as the   | Query Exceeded:          no
# long - faced sad sack ... and his chemistry | Victim Model Queries:    111
# with Shimizu is very believable .           | Succeed:                 no
#                                             |
# Sample: 528 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# Young Hanks and Fisk , who vaguely resemble |
# young hanks and fisk , who vaguely resemble |
#                                             | Running Time:            0.0049698
# their celebrity parents , bring fresh       | Query Exceeded:          no
# their celebrity parents , bring fresh       | Victim Model Queries:    166
#                                             | Semantic Similarity:     0.9715985
# good      looks and an ease in front of the | Grammatical Errors:      5
# estimable looks and an ease in front of the | Succeed:                 yes
#                                             |
# camera to the work .                        |
# camera to the work .                        |
#                                             |
# Sample: 529 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             |
# A captivatingly       quirky hybrid of      | Running Time:            0.0051427
# a captivatingly far - out    hybrid of      | Query Exceeded:          no
#                                             | Victim Model Queries:    79
# character portrait , romantic comedy and    | Semantic Similarity:     0.8588252
# character portrait , romantic comedy and    | Grammatical Errors:      4
#                                             | Succeed:                 yes
# beat - the - clock thriller .               |
# beat - the - clock thriller .               |
#                                             |
# Sample: 530 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             | Running Time:            0.0026612
# The film sparkles with the the wisdom and   | Query Exceeded:          no
# the film light    with the the wisdom and   | Victim Model Queries:    70
#                                             | Semantic Similarity:     0.8952863
# humor of its subjects .                     | Grammatical Errors:      3
# humor of its subjects .                     | Succeed:                 yes
#                                             |
# Sample: 531 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0040455
# If ( Jaglom ' s ) latest effort is not the  | Query Exceeded:          no
# director at his most sparkling , some of    | Victim Model Queries:    118
# its repartee is still worth hearing .       | Succeed:                 no
#                                             |
# Sample: 532 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# Like The English Patient  and The           |
# like the english affected and the           |
#                                             |
# Unbearable  Lightness of Being , The Hours  |
# intolerable elation   of being , the hour   |
#                                             | Running Time:            0.0066767
# is one of those reputedly `` unfilmable ''  | Query Exceeded:          no
# is one of those reputedly `` unfilmable ''  | Victim Model Queries:    181
#                                             | Semantic Similarity:     0.6049752
# novels that has  bucked the odds    to      | Grammatical Errors:      6
# novel  that have buck   the betting to      | Succeed:                 yes
#                                             |
# emerge as an exquisite motion  picture in   |
# issue  as an keen      gesture image   in   |
#                                             |
# its own right      .                        |
# its ain rightfield .                        |
#                                             |
# Sample: 533 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             | Running Time:            0.00456
# Just about the best    straight - up , old  | Query Exceeded:          no
# just about the serious straight - up , old  | Victim Model Queries:    127
#                                             | Semantic Similarity:     0.8732545
# - school horror film of the last 15 years . | Grammatical Errors:      3
# - school horror film of the last 15 years . | Succeed:                 yes
#                                             |
# Sample: 534 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# A chilling tale of one of the great crimes  | Running Time:            0.0044465
# a chilling tale of one of the bully crimes  | Query Exceeded:          no
#                                             | Victim Model Queries:    110
# of 20th Century France : the murder of two  | Semantic Similarity:     0.9429901
# of 20th century france : the murder of two  | Grammatical Errors:      3
#                                             | Succeed:                 yes
# rich women by their servants in 1933 .      |
# rich women by their servants in 1933 .      |
#                                             |
# Sample: 535 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# An oddity , to be sure    , but one that    | Running Time:            0.0029783
# an oddity , to be trusted , but one that    | Query Exceeded:          no
#                                             | Victim Model Queries:    94
# you might wind up remembering with a degree | Semantic Similarity:     0.9223024
# you might wind up remembering with a degree | Grammatical Errors:      4
#                                             | Succeed:                 yes
# of affection rather than revulsion .        |
# of affection rather than revulsion .        |
#                                             |
# Sample: 536 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# While the film is not entirely successful , | Running Time:            0.0056698
# while the film is not entirely successful , | Query Exceeded:          no
#                                             | Victim Model Queries:    147
# it still manages to string together enough  | Semantic Similarity:     0.9082128
# it still manages to string together enough  | Grammatical Errors:      3
#                                             | Succeed:                 yes
# charming moments to work .                  |
# capture  moments to work .                  |
#                                             |
# Sample: 537 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0038688
# A winning piece of work filled with love    | Query Exceeded:          no
# for the movies of the 1960s .               | Victim Model Queries:    93
#                                             | Succeed:                 no
#                                             |
# Sample: 538 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             |
# E . T . works because its flabbergasting    | Running Time:            0.015178
# principals , 14 - year - old Robert         | Query Exceeded:          no
# MacNaughton , 6 - year - old Drew Barrymore | Victim Model Queries:    244
# and 10 - year - old Henry Thomas , convince | Succeed:                 no
# us of the existence of the wise , wizened   |
# visitor from a faraway planet .             |
#                                             |
# Sample: 539 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0059943
# Helps to remind the First World that HIV \/ | Query Exceeded:          no
# AIDS is far from being yesterday ' s news . | Victim Model Queries:    100
#                                             | Succeed:                 no
#                                             |
# Sample: 540 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             | Running Time:            0.0033357
# A heartening tale of small  victories and   | Query Exceeded:          no
# a heartening tale of modest victories and   | Victim Model Queries:    71
#                                             | Semantic Similarity:     0.9035139
# enduring hope .                             | Grammatical Errors:      2
# enduring hope .                             | Succeed:                 yes
#                                             |
# Sample: 541 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             | Running Time:            0.00248
# The vistas are sweeping and the acting is   | Query Exceeded:          no
# the vistas are sweeping and the acting is   | Victim Model Queries:    49
#                                             | Semantic Similarity:     0.9101833
# far from painful    .                       | Grammatical Errors:      4
# far from afflictive .                       | Succeed:                 yes
#                                             |
# Sample: 542 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             | Running Time:            0.0051882
# Jackson and co have brought back the value  | Query Exceeded:          no
# jackson and co have brought back the value  | Victim Model Queries:    102
#                                             | Semantic Similarity:     0.9311464
# and respect for the term epic cinema .      | Grammatical Errors:      3
# and respect for the term epos cinema .      | Succeed:                 yes
#                                             |
# Sample: 543 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# It may be a somewhat backhanded compliment  |
# it may be a somewhat backhanded compliment  |
#                                             |
# to say that the film makes the viewer feel  |
# to say that the film crap  the viewer feel  |
#                                             | Running Time:            0.020357
# like the movie ' s various victimized       | Query Exceeded:          no
# like the movie ' s various victimized       | Victim Model Queries:    266
#                                             | Semantic Similarity:     0.9827569
# audience members after a while , but it     | Grammatical Errors:      4
# audience members after a while , but it     | Succeed:                 yes
#                                             |
# also happens to be the movie ' s most       |
# also happens to be the movie ' s most       |
#                                             |
# admirable quality                           |
# admirable quality                           |
#                                             |
# Sample: 544 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             | Running Time:            0.011016
#                                             | Query Exceeded:          no
# Charlotte Sometimes is a brilliant movie .  | Victim Model Queries:    31
# charlotte sometimes is a brainy    movie .  | Semantic Similarity:     0.8787735
#                                             | Grammatical Errors:      3
#                                             | Succeed:                 yes
#                                             |
# Sample: 545 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# It is about irrational , unexplainable life | Running Time:            0.0060115
# it is about irrational , unexplainable life | Query Exceeded:          no
#                                             | Victim Model Queries:    106
# and it seems so real     because it does    | Semantic Similarity:     0.946115
# and it seems so existent because it does    | Grammatical Errors:      4
#                                             | Succeed:                 yes
# not attempt to filter out the complexity .  |
# not attempt to filter out the complexity .  |
#                                             |
# Sample: 546 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0087206
# A delightful stimulus for the optic nerves  | Query Exceeded:          no
# , so much that it ' s forgivable that the   | Victim Model Queries:    107
# plot feels like every other tale of a       | Succeed:                 no
# totalitarian tomorrow .                     |
#                                             |
# Sample: 547 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             |
# Defies logic , the laws    of physics and   | Running Time:            0.006803
# defies logic , the natural of physics and   | Query Exceeded:          no
#                                             | Victim Model Queries:    52
# almost anyone ' s willingness to believe in | Semantic Similarity:     0.8969534
# almost anyone ' s willingness to believe in | Grammatical Errors:      4
#                                             | Succeed:                 yes
# it .                                        |
# it .                                        |
#                                             |
# Sample: 548 ===================================================================
# Label: 0 (100.00%) --> Failed!              |
#                                             | Running Time:            0.012737
# But darned if it does n ' t also keep us    | Query Exceeded:          no
# riveted to our seats .                      | Victim Model Queries:    120
#                                             | Succeed:                 no
#                                             |
# Sample: 549 ===================================================================
# Label: 0 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0076702
# A complex psychological drama about a       | Query Exceeded:          no
# father who returns to his son ' s home      | Victim Model Queries:    105
# after decades away .                        | Succeed:                 no
#                                             |
# Sample: 550 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             |
# Writer and director Otar Iosseliani ' s     | Running Time:            0.018202
# pleasant tale about a factory worker who    | Query Exceeded:          no
# escapes for a holiday in Venice reveals how | Victim Model Queries:    149
# we all need a playful respite from the      | Succeed:                 no
# grind to refresh our souls .                |
#                                             |
# Sample: 551 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             | Running Time:            0.005688
# This is NOT a retread of `` Dead Poets '    | Query Exceeded:          no
# this is not a retread of `` dead poets '    | Victim Model Queries:    47
#                                             | Semantic Similarity:     0.8742151
# Society . ''                                | Grammatical Errors:      4
# smart   . ''                                | Succeed:                 yes
#                                             |
# Sample: 552 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0018661
#                                             | Query Exceeded:          no
# Sweet and memorable film .                  | Victim Model Queries:    31
#                                             | Succeed:                 no
#                                             |
# Sample: 553 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             | Running Time:            0.0048635
# A smart , arch and rather cold - blooded    | Query Exceeded:          no
# a chic  , arch and rather cold - blooded    | Victim Model Queries:    59
#                                             | Semantic Similarity:     0.8102721
# comedy .                                    | Grammatical Errors:      4
# comedy .                                    | Succeed:                 yes
#                                             |
# Sample: 554 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# Keenly observed and refreshingly            |
# keenly detect   and refreshfully            |
#                                             |
# natural     , Swimming gets the details     |
# instinctive , swim     get  the inside      |
#                                             | Running Time:            0.015638
# right , from its promenade of barely clad   | Query Exceeded:          no
# flop  , from its prom      of hardly clad   | Victim Model Queries:    261
#                                             | Semantic Similarity:     0.8140586
# bodies in Myrtle Beach , S . C . , to the   | Grammatical Errors:      10
# bodies in myrtle beach , s . c . , to the   | Succeed:                 yes
#                                             |
# adrenaline jolt of a sudden lunch rush at   |
# adrenaline jolt of a sudden lunch rush at   |
#                                             |
# the diner .                                 |
# the diner .                                 |
#                                             |
# Sample: 555 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0061138
# ... begins on a high note and sustains it   | Query Exceeded:          no
# beautifully .                               | Victim Model Queries:    71
#                                             | Succeed:                 no
#                                             |
# Sample: 556 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0095732
# Davis ... gets vivid performances from her  | Query Exceeded:          no
# cast and pulls off some deft Ally McBeal -  | Victim Model Queries:    163
# style fantasy sequences .                   | Succeed:                 no
#                                             |
# Sample: 557 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             |
# ` it ' s better to go in knowing full well  | Running Time:            0.016176
# what ' s going to happen , but willing to   | Query Exceeded:          no
# let the earnestness of its execution and    | Victim Model Queries:    392
# skill of its cast take you down a familiar  | Succeed:                 no
# road with a few twists .                    |
#                                             |
# Sample: 558 ===================================================================
# Label: 0 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0030398
#                                             | Query Exceeded:          no
# Cynics need not apply . '                   | Victim Model Queries:    31
#                                             | Succeed:                 no
#                                             |
# Sample: 559 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             |
# Funny , somber , absurd , and , finally ,   | Running Time:            0.0043252
# funny , somber , the    , and , finally ,   | Query Exceeded:          no
#                                             | Victim Model Queries:    68
# achingly sad , Bartleby is a fine ,         | Semantic Similarity:     0.9634536
# achingly sad , bartleby is a fine ,         | Grammatical Errors:      10
#                                             | Succeed:                 yes
# understated piece of filmmaking .           |
# understated piece of filmmaking .           |
#                                             |
# Sample: 560 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             | Running Time:            0.0020826
#                                             | Query Exceeded:          no
# `` Red Dragon '' is entertaining .          | Victim Model Queries:    41
# `` red dragon '' is entertain    .          | Semantic Similarity:     0.9206764
#                                             | Grammatical Errors:      2
#                                             | Succeed:                 yes
#                                             |
# Sample: 561 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             | Running Time:            0.0051239
# An obvious copy of one of the best          | Query Exceeded:          no
# an obvious copy of one of the estimable     | Victim Model Queries:    138
#                                             | Semantic Similarity:     0.9196468
# films ever made , how could it not be ?     | Grammatical Errors:      2
# films ever made , how could it not be ?     | Succeed:                 yes
#                                             |
# Sample: 562 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             | Running Time:            0.0031996
# But it is entertaining on an inferior level | Query Exceeded:          no
# but it is entertain    on an inferior level | Victim Model Queries:    39
#                                             | Semantic Similarity:     0.9105814
# .                                           | Grammatical Errors:      3
# .                                           | Succeed:                 yes
#                                             |
# Sample: 563 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             | Running Time:            0.0032296
# It is a popcorn film , not a must - own ,   | Query Exceeded:          no
# it is a popcorn film , not a must - own ,   | Victim Model Queries:    91
#                                             | Semantic Similarity:     0.7851539
# or even a must - see .                      | Grammatical Errors:      4
# or even a must - see .                      | Succeed:                 yes
#                                             |
# Sample: 564 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             | Running Time:            0.004909
# Succeeds only because Bullock and Grant     | Query Exceeded:          no
# succeed  only because bullock and grant     | Victim Model Queries:    143
#                                             | Semantic Similarity:     0.9541262
# were made to share the silver screen .      | Grammatical Errors:      2
# were made to share the silver screen .      | Succeed:                 yes
#                                             |
# Sample: 565 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# Both flawed and delayed , Martin Scorcese ' | Running Time:            0.0063579
# both flawed and retard  , martin scorcese ' | Query Exceeded:          no
#                                             | Victim Model Queries:    84
# s Gangs of New York still emerges as his    | Semantic Similarity:     0.9814367
# s gangs of new york still emerges as his    | Grammatical Errors:      6
#                                             | Succeed:                 yes
# most vital work since GoodFellas .          |
# most vital work since goodfellas .          |
#                                             |
# Sample: 566 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# As any creature - feature fan knows , when  |
# as any creature - feature fan knows , when  |
#                                             | Running Time:            0.011482
# you cross toxic chemicals with a bunch of   | Query Exceeded:          no
# you cross toxic chemicals with a bunch of   | Victim Model Queries:    280
#                                             | Semantic Similarity:     0.8696151
# exotic creatures , you get a lot of running | Grammatical Errors:      5
# alien  creatures , you get a lot of running | Succeed:                 yes
#                                             |
# around , screaming and death .              |
# around , screaming and death .              |
#                                             |
# Sample: 567 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             | Running Time:            0.0035458
# On that score , the film certainly does n ' | Query Exceeded:          no
# on that score , the film for       does n ' | Victim Model Queries:    86
#                                             | Semantic Similarity:     0.8719061
# t disappoint .                              | Grammatical Errors:      4
# t disappoint .                              | Succeed:                 yes
#                                             |
# Sample: 568 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# As the movie traces Mr . Brown ' s athletic |
# as the movie traces mr . brown ' s athletic |
#                                             |
# exploits , it is impossible not to be awed  | Running Time:            0.011783
# exploits , it is impossible not to be awed  | Query Exceeded:          no
#                                             | Victim Model Queries:    168
# by the power and grace of one of the        | Semantic Similarity:     0.9438427
# by the power and grace of one of the        | Grammatical Errors:      6
#                                             | Succeed:                 yes
# greatest natural sportsmen of modern times  |
# sterling natural sportsmen of modern times  |
#                                             |
# .                                           |
# .                                           |
#                                             |
# Sample: 569 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0074682
# A moving and solidly entertaining comedy \/ | Query Exceeded:          no
# drama that should bolster director and co - | Victim Model Queries:    92
# writer Juan José Campanella ' s reputation  | Succeed:                 no
# in the United States .                      |
#                                             |
# Sample: 570 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0084097
# Thanks to confident filmmaking and a pair   | Query Exceeded:          no
# of fascinating performances , the way to    | Victim Model Queries:    127
# that destination is a really special walk   | Succeed:                 no
# in the woods .                              |
#                                             |
# Sample: 571 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0060418
# Beautifully shot , delicately scored and    | Query Exceeded:          no
# powered by a set of heartfelt performances  | Victim Model Queries:    87
# , it ' s a lyrical endeavour .              | Succeed:                 no
#                                             |
# Sample: 572 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0092864
# A macabre and very stylized Swedish fillm   | Query Exceeded:          no
# about a modern city where all the religious | Victim Model Queries:    160
# and civic virtues that hold society in      | Succeed:                 no
# place are in tatters .                      |
#                                             |
# Sample: 573 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0033081
# A stylistic romp that ' s always fun to     | Query Exceeded:          no
# watch .                                     | Victim Model Queries:    68
#                                             | Succeed:                 no
#                                             |
# Sample: 574 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0073228
# Informative , intriguing , observant ,      | Query Exceeded:          no
# often touching ... gives a human face to    | Victim Model Queries:    172
# what ' s often discussed in purely abstract | Succeed:                 no
# terms .                                     |
#                                             |
# Sample: 575 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             | Running Time:            0.0028713
# ... once the true impact of the day unfolds | Query Exceeded:          no
# ... once the dead impact of the day unfolds | Victim Model Queries:    92
#                                             | Semantic Similarity:     0.8909929
# , the power of this movie is undeniable .   | Grammatical Errors:      2
# , the power of this movie is undeniable .   | Succeed:                 yes
#                                             |
# Sample: 576 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0031643
# An honest , sensitive story from a          | Query Exceeded:          no
# Vietnamese point of view .                  | Victim Model Queries:    82
#                                             | Succeed:                 no
#                                             |
# Sample: 577 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# A buoyant romantic comedy about friendship  | Running Time:            0.0035455
# a buoyant romantic comedy about friendship  | Query Exceeded:          no
#                                             | Victim Model Queries:    59
# , love    , and the truth that we ' re all  | Semantic Similarity:     0.9527309
# , passion , and the truth that we ' re all  | Grammatical Errors:      5
#                                             | Succeed:                 yes
# in this together .                          |
# in this together .                          |
#                                             |
# Sample: 578 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# The film ' s intimate  camera work and      |
# the film ' s confidant camera work and      |
#                                             |
# searing performances pull us deep into the  | Running Time:            0.0082333
# searing performances pull us deep into the  | Query Exceeded:          no
#                                             | Victim Model Queries:    196
# girls ' confusion and pain as they struggle | Semantic Similarity:     0.9642788
# girls ' confusion and pain as they struggle | Grammatical Errors:      5
#                                             | Succeed:                 yes
# tragically to comprehend the chasm of       |
# tragically to comprehend the chasm of       |
#                                             |
# knowledge that ' s opened between them .    |
# knowledge that ' s opened between them .    |
#                                             |
# Sample: 579 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# It ' s the perfect star vehicle for Grant , |
# it ' s the arrant  star vehicle for grant , |
#                                             | Running Time:            0.0066347
# allowing him to finally move away from his  | Query Exceeded:          no
# allowing him to finally move away from his  | Victim Model Queries:    149
#                                             | Semantic Similarity:     0.8352294
# usual bumbling , tongue - tied screen       | Grammatical Errors:      5
# usual bumbling , tongue - tied screen       | Succeed:                 yes
#                                             |
# persona .                                   |
# persona .                                   |
#                                             |
# ...
# Sample: 985 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0047078
# Wickedly funny , visually engrossing ,      | Query Exceeded:          no
# never boring , this movie challenges us to  | Victim Model Queries:    149
# think about the ways we consume pop culture | Succeed:                 no
# .                                           |
#                                             |
# Sample: 986 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             | Running Time:            0.0025172
#                                             | Query Exceeded:          no
# There ' s plenty to impress about E . T .   | Victim Model Queries:    76
# there ' s good   to impress about e . t .   | Semantic Similarity:     0.6172933
#                                             | Grammatical Errors:      3
#                                             | Succeed:                 yes
#                                             |
# Sample: 987 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             |
# A chronicle not only of one man ' s quest   |
# a chronicle not only of one man ' s quest   |
#                                             |
# to be president , but of how that man       |
# to be president , but of how that man       |
#                                             | Running Time:            0.015919
# single - handedly turned a plane full of    | Query Exceeded:          no
# single - handedly turned a plane full of    | Victim Model Queries:    233
#                                             | Semantic Similarity:     0.9514680
# hard   - bitten , cynical journalists into  | Grammatical Errors:      9
# strong - bitten , cynical journalists into  | Succeed:                 yes
#                                             |
# what was essentially , by campaign ' s end  |
# what was essentially , by campaign ' s end  |
#                                             |
# , an extended publicity department .        |
# , an extended publicity department .        |
#                                             |
# Sample: 988 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# Until it goes off the rails in its final 10 |
# until it goes off the rails in its final 10 |
#                                             |
# or 15 minutes , Wendigo , Larry Fessenden ' |
# or 15 minutes , wendigo , larry fessenden ' |
#                                             | Running Time:            0.013294
# s spooky new thriller , is a refreshingly   | Query Exceeded:          no
# s spooky new thriller , is a refreshingly   | Victim Model Queries:    239
#                                             | Semantic Similarity:     0.9629158
# smart and newfangled variation on several   | Grammatical Errors:      8
# smart and newfangled variation on several   | Succeed:                 yes
#                                             |
# themes derived from far less sophisticated  |
# base   derived from far less sophisticated  |
#                                             |
# and knowing horror films .                  |
# and knowing horror films .                  |
#                                             |
# Sample: 989 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0027626
# ( Woo ' s ) most resonant film since The    | Query Exceeded:          no
# Killer .                                    | Victim Model Queries:    61
#                                             | Succeed:                 no
#                                             |
# Sample: 990 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             |
# Collateral Damage is trash , but it earns   | Running Time:            0.0071783
# collateral legal  is trash , but it earns   | Query Exceeded:          no
#                                             | Victim Model Queries:    127
# extra points by acting as if it were n ' t  | Semantic Similarity:     0.7399466
# extra points by acting as if it were n ' t  | Grammatical Errors:      4
#                                             | Succeed:                 yes
# .                                           |
# .                                           |
#                                             |
# Sample: 991 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# A whole lot of fun       and funny in the   | Running Time:            0.0064857
# a whole lot of merriment and funny in the   | Query Exceeded:          no
#                                             | Victim Model Queries:    150
# middle , though somewhat less hard -        | Semantic Similarity:     0.8947793
# middle , though somewhat less hard -        | Grammatical Errors:      4
#                                             | Succeed:                 yes
# hitting at the start and finish .           |
# hitting at the start and finish .           |
#                                             |
# Sample: 992 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             |
# Maybe it is formula filmmaking , but there  | Running Time:            0.016568
# maybe it is formula filmmaking , but there  | Query Exceeded:          no
#                                             | Victim Model Queries:    102
# ' s nothing wrong with that if the film is  | Semantic Similarity:     0.9274679
# ' s nothing wrong with that if the film is  | Grammatical Errors:      4
#                                             | Succeed:                 yes
# well - crafted and this one is .            |
# good - crafted and this one is .            |
#                                             |
# Sample: 993 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             |
# ( Fincher ' s ) camera sense and assured    | Running Time:            0.0070314
# ( fincher ' s ) camera good  and assured    | Query Exceeded:          no
#                                             | Victim Model Queries:    136
# pacing make it an above - average thriller  | Semantic Similarity:     0.9180826
# pacing make it an above - average thriller  | Grammatical Errors:      4
#                                             | Succeed:                 yes
# .                                           |
# .                                           |
#                                             |
# Sample: 994 ===================================================================
# Label: 0 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0026035
# The film is insightful about Kissinger ' s  | Query Exceeded:          no
# background and history .                    | Victim Model Queries:    48
#                                             | Succeed:                 no
#                                             |
# Sample: 995 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0085256
# An engrossing portrait of a man whose       | Query Exceeded:          no
# engaging manner and flamboyant style made   | Victim Model Queries:    207
# him a truly larger - than - life character  | Succeed:                 no
# .                                           |
#                                             |
# Sample: 996 ===================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             |
# A lot of the credit for the film ' s        | Running Time:            0.015514
# winning tone must go to Grant , who has n ' | Query Exceeded:          no
# t lost a bit of the dry humor that first    | Victim Model Queries:    402
# made audiences on both sides of the         | Succeed:                 no
# Atlantic love him .                         |
#                                             |
# Sample: 997 ===================================================================
# Label: 1 (100.00%) --> 0 (100.00%)          |
#                                             |
# Exploits ( headbanger ) stereotypes in good | Running Time:            0.0062513
# exploits ( headbanger ) stereotypes in full | Query Exceeded:          no
#                                             | Victim Model Queries:    142
# fun , while adding a bit of heart and       | Semantic Similarity:     0.9682164
# fun , while adding a bit of heart and       | Grammatical Errors:      6
#                                             | Succeed:                 yes
# unsettling subject matter .                 |
# unsettling subject matter .                 |
#                                             |
# Sample: 998 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             |
# A journey that is as difficult for the      |
# a journey that is as hard      for the      |
#                                             | Running Time:            0.0056522
# audience to take as it is for the           | Query Exceeded:          no
# audience to take as it is for the           | Victim Model Queries:    117
#                                             | Semantic Similarity:     0.9766279
# protagonist -- yet it ' s potentially just  | Grammatical Errors:      3
# protagonist -- yet it ' s potentially just  | Succeed:                 yes
#                                             |
# as rewarding .                              |
# as rewarding .                              |
#                                             |
# Sample: 999 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             |
# Ratliff ' s two previous titles , Plutonium |
# ratliff ' s two old      title  , pu        |
#                                             |
# Circus   and Purgatory County show his      | Running Time:            0.0094626
# carnival and purgatory county demo his      | Query Exceeded:          no
#                                             | Victim Model Queries:    153
# penchant   for wry , contentious            | Semantic Similarity:     0.776783
# preference for wry , combative              | Grammatical Errors:      6
#                                             | Succeed:                 yes
# configurations , and this film  is part     |
# configuration  , and this movie is portion  |
#                                             |
# of that delicate canon .                    |
# of that fragile  canon .                    |
#                                             |
# Sample: 1000 ==================================================================
# Label: 1 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0086172
# From its invitingly upbeat overture to its  | Query Exceeded:          no
# pathos - filled but ultimately life -       | Victim Model Queries:    133
# affirming finale , Martin is a masterfully  | Succeed:                 no
# conducted work .                            |
#                                             |
# +========================================+
# |                Summary                 |
# +========================================+
# | Total Attacked Instances:  | 1000      |
# | Successful Instances:      | 571       |
# | Attack Success Rate:       | 0.571     |
# | Avg. Running Time:         | 0.0082886 |
# | Total Query Exceeded:      | 0         |
# | Avg. Victim Model Queries: | 120.88    |
# | Avg. Semantic Similarity:  | 0.89191   |
# | Avg. Grammatical Errors:   | 4.1944    |
# +========================================+

# %%
import OpenAttack
from textblob import TextBlob
from datasets import load_dataset

# 定义一个使用 TextBlob 的情感分类模型
class TextBlobClassifier(OpenAttack.Classifier):
    def __init__(self):
        pass

    def get_prob(self, input_):
        sentiment = TextBlob(input_).sentiment.polarity
        prob = (sentiment + 1) / 2  # 将情感极性值映射到 [0, 1] 区间
        return [1 - prob, prob]  # 返回负面和正面情感的概率

def dataset_mapping(x):
    return {
        "x": x["review_body"],
        "y": x["stars"],
    }

def main():
    print("New Attacker")
    attacker = OpenAttack.attackers.TextFoolerAttacker()

    print("Building model")
    victim = TextBlobClassifier()

    print("Loading dataset")
    dataset = load_dataset("amazon_reviews_multi", "zh", split="train[:20]").map(function=dataset_mapping)

    print("Start attack")
    attack_data = [(example["x"], 1 if example["y"] > 3 else 0) for example in dataset]
    attack_eval = OpenAttack.AttackEval(attacker, victim)
    attack_eval.eval(attack_data, visualize=True, progress_bar=True)

if __name__ == "__main__":
    main()
# Out:
# New Attacker
# Building model
# Loading dataset
# WARNING:datasets.builder:Found cached dataset amazon_reviews_multi (/root/.cache/huggingface/datasets/amazon_reviews_multi/zh/1.0.0/724e94f4b0c6c405ce7e476a6c5ef4f87db30799ad49f765094cf9770e0f7609)
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/amazon_reviews_multi/zh/1.0.0/724e94f4b0c6c405ce7e476a6c5ef4f87db30799ad49f765094cf9770e0f7609/cache-5369624ec470d3ab.arrow
# Start attack
#   0%|          | 0/20 [00:00<?, ?it/s]ERROR:OpenAttack.AttackEval:Exception when evaluate data ('本人账号被盗，资金被江西（杨建）挪用，请亚马逊尽快查实，将本人的200元资金退回。本人已于2017年11月30日提交退货申请，为何到2018年了还是没解决？亚马逊是什么情况？请给本人一个合理解释。', 0)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/OpenAttack/attack_eval/utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#   File "/usr/local/lib/python3.9/dist-packages/OpenAttack/attackers/classification.py", line 16, in __call__
#     raise AttributeError("`%s` needs victim to support `%s` method" % (self.__class__.__name__, "get_pred"))
# AttributeError: `TextFoolerAttacker` needs victim to support `get_pred` method
#   0%|          | 0/20 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-4b48f12dbea6> in <cell line: 36>()
#      35
#      36 if __name__ == "__main__":
# ---> 37     main()
#
# <ipython-input-2-4b48f12dbea6> in main()
#      32     attack_data = [(example["x"], 1 if example["y"] > 3 else 0) for example in dataset]
#      33     attack_eval = OpenAttack.AttackEval(attacker, victim)
# ---> 34     attack_eval.eval(attack_data, visualize=True, progress_bar=True)
#      35
#      36 if __name__ == "__main__":
#
# /usr/local/lib/python3.9/dist-packages/OpenAttack/attack_eval/attack_eval.py in eval(self, dataset, total_len, visualize, progress_bar, num_workers, chunk_size)
#     182
#     183             if visualize and (TAG_Classification in self.victim.TAGS):
# --> 184                 x_orig = res["data"]["x"]
#     185                 if res["success"]:
#     186                     x_adv = res["result"]
#
# TypeError: tuple indices must be integers or slices, not str

# %%
# !pip install datasets
# !pip install language_tool_python
# !pip install strsimpy
# !pip install openattack
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 29.1 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 67.4 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.11.0 (from datasets)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Collecting responses<0.19 (from datasets)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 10.8 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 35.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 23.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.12.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.14.1 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.9.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting language_tool_python
#   Downloading language_tool_python-2.7.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from language_tool_python) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from language_tool_python) (4.65.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->language_tool_python) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->language_tool_python) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->language_tool_python) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->language_tool_python) (3.4)
# Installing collected packages: language_tool_python
# Successfully installed language_tool_python-2.7.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting strsimpy
#   Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: strsimpy
# Successfully installed strsimpy-0.2.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openattack
#   Downloading OpenAttack-2.1.1-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.5 in /usr/local/lib/python3.10/dist-packages (from openattack) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openattack) (1.22.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from openattack) (2.12.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openattack) (4.65.0)
# Collecting transformers>=4.0.0 (from openattack)
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 84.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from openattack) (2.0.0+cu118)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.5->openattack) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.5->openattack) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.5->openattack) (2022.10.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.1->openattack) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.1->openattack) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.1->openattack) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.1->openattack) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.1->openattack) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.1->openattack) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.5.1->openattack) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.5.1->openattack) (16.0.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->openattack) (0.14.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->openattack) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->openattack) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->openattack) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers>=4.0.0->openattack)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 27.6 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->openattack) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->openattack) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->openattack) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->openattack) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->openattack) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets->openattack) (2023.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->openattack) (3.8.4)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets->openattack) (0.18.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openattack) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openattack) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openattack) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openattack) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openattack) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openattack) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openattack) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.0.0->openattack) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.0.0->openattack) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.0.0->openattack) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.5.1->openattack) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->openattack) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->openattack) (2022.7.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.5.1->openattack) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->openattack) (1.16.0)
# Installing collected packages: tokenizers, transformers, openattack
# Successfully installed openattack-2.1.1 tokenizers-0.13.3 transformers-4.28.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.6 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import OpenAttack
import numpy as np
import datasets
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

class MyClassifier(OpenAttack.Classifier):
    def __init__(self):
        self.analyzer = SentimentIntensityAnalyzer()

    def get_pred(self, input_):
        return self.get_prob(input_).argmax(axis=1)

    """def get_prob(self, input_):
        ret = []
        for sent in input_:
            vs = self.analyzer.polarity_scores(sent)
            if vs['compound'] > 0:
                ret.append(np.array([0, 1]))
            else:
                ret.append(np.array([1, 0]))
        return np.array(ret)"""
    def get_prob(self, input_):
        ret = []
        for sent in input_:
            # SentimentIntensityAnalyzer calculates scores of “neg” and “pos” for each instance
            res = self.analyzer.polarity_scores(sent)

            # we use 𝑠𝑜𝑐𝑟𝑒_𝑝𝑜𝑠 / (𝑠𝑐𝑜𝑟𝑒_𝑛𝑒𝑔 + 𝑠𝑐𝑜𝑟𝑒_𝑝𝑜𝑠) to represent the probability of positive sentiment
            # Adding 10^−6 is a trick to avoid dividing by zero.
            prob = (res["pos"] + 1e-6) / (res["neg"] + res["pos"] + 2e-6)

            ret.append(np.array([1 - prob, prob]))

        # The get_prob method finally returns a np.ndarray of shape (len(input_), 2). See Classifier for detail.
        return np.array(ret)

def dataset_mapping(x):
    return {
        "x": x["text"],
        "y": 1 if x["label"] > 0.5 else 0,
    }

def main():
    # 从 datasets 库中加载 IMDB 数据集的前 2000 个样本
    imdb_train = datasets.load_dataset("imdb", split="test[:500]").map(function=dataset_mapping)

    # 使用自定义分类器作为受害者模型
    victim = MyClassifier()

    # 选择 PWWS 作为攻击者并使用默认参数初始化
    #attacker = OpenAttack.attackers.TextFoolerAttacker()
    attacker = OpenAttack.attackers.PWWSAttacker()
    attack_eval = OpenAttack.AttackEval(attacker, victim, metrics = [
        OpenAttack.metric.SemanticSimilarity(),
        OpenAttack.metric.GrammaticalErrors(),
        # OpenAttack.metric.Fluency()
        # OpenAttack.metric.EditDistance(),
        # OpenAttack.metric.ModificationRate(),
    ])
    attack_eval.eval(imdb_train, visualize=True)


if __name__ == "__main__":
    main()
# Out:
# WARNING:datasets.builder:Found cached dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/d613c88cf8fa3bab83b4ded3713f1f74830d1100e171db75bbddb80b3345c9c0)
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/d613c88cf8fa3bab83b4ded3713f1f74830d1100e171db75bbddb80b3345c9c0/cache-adcb397d59770676.arrow
# Sample: 1 =====================================================================
# Label: 1 (59.92%) --> 0 (52.27%)            |
#                                             |
# I love sci - fi and am willing to put up    |
# i love sci - fi and am willing to put up    |
#                                             |
# with a lot . Sci - fi movies / TV are       |
# with a lot . sci - fi movies / tv are       |
#                                             |
# usually underfunded , under - appreciated   |
# usually underfunded , under - appreciated   |
#                                             |
# and misunderstood . I tried to like this ,  |
# and misunderstood . i tried to like this ,  |
#                                             |
# I really did , but it is to good TV    sci  |
# i really did , but it is to good idiot sci  |
#                                             |
# - fi as Babylon 5 is to Star Trek ( the     |
# - fi as babylon 5 is to star trek ( the     |
#                                             |
# original ). Silly prosthetics , cheap       |
# original ). silly prosthetics , cheap       |
#                                             |
# cardboard sets , stilted dialogues , CG     |
# cardboard sets , stilted dialogues , cg     |
#                                             |
# that doesn ' t match the background , and   |
# that doesn ' t match the background , and   |
#                                             |
# painfully one - dimensional characters      |
# painfully one - dimensional characters      |
#                                             |
# cannot be overcome with a ' sci - fi '      |
# cannot be overcome with a ' sci - fi '      |
#                                             |
# setting . ( I ' m sure there are those of   |
# setting . ( i ' m sure there are those of   |
#                                             |
# you out there who think Babylon 5 is good   |
# you out there who think babylon 5 is good   |
#                                             |
# sci - fi TV . It ' s not . It ' s clichéd   |
# sci - fi tv . it ' s not . it ' s clichéd   |
#                                             |
# and uninspiring .) While US viewers might   |
# and uninspiring .) while us viewers might   |
#                                             |
# like emotion and character development ,    |
# like emotion and character development ,    |
#                                             |
# sci - fi is a genre that does not take      |
# sci - fi is a genre that does not take      |
#                                             |
# itself seriously ( cf . Star Trek ). It may | Running Time:            0.1846
# itself seriously ( cf . star trek ). it may | Query Exceeded:          no
#                                             | Victim Model Queries:    1514
# treat important issues , yet not as a       | Semantic Similarity:     0.9726249
# treat important issues , yet not as a       | Grammatical Errors:      77
#                                             | Levenshtein Edit Dista:  37
# serious philosophy . It ' s really          | Succeed:                 yes
# serious philosophy . it ' s really          |
#                                             |
# difficult to care  about the characters     |
# difficult to worry about the characters     |
#                                             |
# here as they are not simply foolish , just  |
# here as they are not simply foolish , just  |
#                                             |
# missing a spark of life . Their actions and |
# missing a spark of life . their actions and |
#                                             |
# reactions are wooden and predictable ,      |
# reactions are wooden and predictable ,      |
#                                             |
# often painful to watch . The makers of      |
# often painful to watch . the makers of      |
#                                             |
# Earth KNOW it ' s rubbish as they have to   |
# earth fuck it ' s rubbish as they have to   |
#                                             |
# always say " Gene Roddenberry ' s Earth     |
# always say " gene roddenberry ' s earth     |
#                                             |
# ..." otherwise people would not continue    |
# ..." otherwise people would not continue    |
#                                             |
# watching . Roddenberry ' s ashes must be    |
# watching . roddenberry ' s ashes must be    |
#                                             |
# turning in their orbit as this dull , cheap |
# turning in their orbit as this dull , cheap |
#                                             |
# , poorly edited ( watching it without       |
# , poorly edited ( watching it without       |
#                                             |
# advert breaks really brings this home )     |
# advert breaks really brings this home )     |
#                                             |
# trudging Trabant of a show lumbers into     |
# trudging trabant of a show lumbers into     |
#                                             |
# space . Spoiler . So , kill off a main      |
# space . spoiler . so , kill off a main      |
#                                             |
# character . And then bring him back as      |
# character . and then bring him back as      |
#                                             |
# another actor . Jeeez ! Dallas all over     |
# another actor . jeeez ! dallas all over     |
#                                             |
# again .                                     |
# again .                                     |
#                                             |
# Sample: 2 =====================================================================
# Label: 0 (51.53%) --> 1 (50.46%)            |
#                                             |
# Worth the entertainment value of a rental , |
# worth the entertainment value of a rental , |
#                                             |
# especially if you like action movies . This |
# especially if you like action movies . this |
#                                             |
# one features the usual car chases , fights  |
# one features the usual car chases , fights  |
#                                             |
# with the great Van Damme kick style ,       |
# with the great van damme kick style ,       |
#                                             |
# shooting battles with the 40 shell load     |
# shooting battles with the 40 shell load     |
#                                             |
# shotgun , and even terrorist style bombs .  |
# shotgun , and even terrorist style bombs .  |
#                                             |
# All of this is entertaining and competently |
# all of this is entertaining and competently |
#                                             |
# handled but there is nothing that really    |
# handled but there is nothing that really    |
#                                             |
# blows you away if you ' ve seen your share  |
# blows you away if you ' ve seen your share  |
#                                             |
# before .< br />< br /> The plot is made     |
# before .< br />< br /> the plot is made     |
#                                             |
# interesting by the inclusion of a rabbit ,  |
# interesting by the inclusion of a rabbit ,  |
#                                             |
# which is clever but hardly profound . Many  |
# which is clever but hardly profound . many  |
#                                             |
# of the characters are heavily stereotyped   |
# of the characters are heavily stereotyped   |
#                                             |
# -- the angry veterans , the terrified       |
# -- the angry veterans , the terrified       |
#                                             |
# illegal aliens , the crooked cops , the     |
# illegal aliens , the crooked cops , the     | Running Time:            0.098039
#                                             | Query Exceeded:          no
# indifferent feds , the bitchy tough lady    | Victim Model Queries:    1552
# indifferent feds , the bitchy tough lady    | Semantic Similarity:     0.9381498
#                                             | Grammatical Errors:      57
# station head , the crooked politician , the | Levenshtein Edit Dista:  23
# station head , the crooked politician , the | Succeed:                 yes
#                                             |
# fat federale who looks like he was typecast |
# fat federale who looks like he was typecast |
#                                             |
# as the Mexican in a Hollywood movie from    |
# as the mexican in a hollywood movie from    |
#                                             |
# the 1940s . All passably acted but again    |
# the 1940s . all passably acted but again    |
#                                             |
# nothing special .< br />< br /> I thought   |
# nothing special .< br />< br /> i thought   |
#                                             |
# the main villains were pretty well done and |
# the main villains were pretty well done and |
#                                             |
# fairly well acted . By the end of the movie |
# fairly well acted . by the end of the movie |
#                                             |
# you certainly knew who the good guys were   |
# you certainly love who the good guys were   |
#                                             |
# and weren ' t . There was an emotional lift |
# and weren ' t . there was an emotional lift |
#                                             |
# as the really bad         ones got their    |
# as the really speculative ones got their    |
#                                             |
# just deserts . Very simplistic , but then   |
# just deserts . very simplistic , but then   |
#                                             |
# you weren ' t expecting Hamlet , right ?    |
# you weren ' t expecting hamlet , right ?    |
#                                             |
# The only thing I found really annoying was  |
# the only thing i found really annoying was  |
#                                             |
# the constant cuts to VDs daughter during    |
# the constant cuts to vds daughter during    |
#                                             |
# the last fight scene .< br />< br /> Not    |
# the last fight scene .< br />< br /> not    |
#                                             |
# bad . Not good . Passable 4 .               |
# bad . not good . passable 4 .               |
#                                             |
# Sample: 3 =====================================================================
# Label: 0 (66.12%) --> 1 (52.70%)            |
#                                             |
# its a totally average film with a few semi  |
# its a totally average film with a few semi  |
#                                             |
# - alright action sequences that make the    |
# - alright action sequences that gain the    |
#                                             |
# plot seem a little better and remind the    |
# plot seem a little better and remind the    |
#                                             |
# viewer of the classic van dam films . parts |
# viewer of the classic van dam films . parts |
#                                             |
# of the plot don ' t make sense and seem to  |
# of the plot don ' t make sense and seem to  |
#                                             |
# be added in to use up time . the end plot   |
# be added in to use up time . the end plot   |
#                                             |
# is that of a very basic type that doesn ' t |
# is that of a very basic type that doesn ' t |
#                                             |
# leave the viewer guessing and any twists    |
# leave the viewer guessing and any twists    | Running Time:            0.094977
#                                             | Query Exceeded:          no
# are obvious from the beginning . the end    | Victim Model Queries:    1068
# are obvious from the beginning . the end    | Semantic Similarity:     0.9661193
#                                             | Grammatical Errors:      17
# scene with the flask backs   don ' t make   | Levenshtein Edit Dista:  2
# scene with the flask support don ' t make   | Succeed:                 yes
#                                             |
# sense as they are added in and seem to have |
# sense as they are added in and seem to have |
#                                             |
# little relevance to the history of van dam  |
# little relevance to the history of van dam  |
#                                             |
# ' s character . not really worth watching   |
# ' s character . not really worth watching   |
#                                             |
# again , bit disappointed in the end         |
# again , bit disappointed in the end         |
#                                             |
# production , even though it is apparent it  |
# production , even though it is apparent it  |
#                                             |
# was shot on a low budget certain shots and  |
# was shot on a low budget certain shots and  |
#                                             |
# sections in the film are of poor directed   |
# sections in the film are of poor directed   |
#                                             |
# quality                                     |
# quality                                     |
#                                             |
# Sample: 4 =====================================================================
# Label: 0 (65.38%) --> 1 (51.69%)            |
#                                             |
# STAR RATING : ***** Saturday Night ****     |
# star rating : ***** saturday night ****     |
#                                             |
# Friday Night *** Friday Morning ** Sunday   |
# friday night *** friday morning ** sunday   |
#                                             |
# Night * Monday Morning < br />< br />       |
# night * monday morning < br />< br />       |
#                                             |
# Former New Orleans homicide cop Jack        |
# former new orleans homicide cop jack        |
#                                             |
# Robideaux ( Jean Claude Van Damme ) is re - |
# robideaux ( jean claude van damme ) is re - |
#                                             |
# assigned to Columbus , a small but violent  |
# assigned to columbus , a small but violent  |
#                                             |
# town in Mexico to help the police there     |
# town in mexico to help the police there     |
#                                             |
# with their efforts to stop a major heroin   |
# with their efforts to stop a major heroin   |
#                                             |
# smuggling operation into their town . The   |
# smuggling operation into their town . the   |
#                                             |
# culprits turn out to be ex - military ,     |
# culprits turn out to be ex - military ,     |
#                                             |
# lead by former commander Benjamin Meyers (  |
# lead by former commander benjamin meyers (  |
#                                             |
# Stephen Lord , otherwise known as Jase from |
# stephen lord , otherwise love  as jase from |
#                                             |
# East Enders ) who is using a special method |
# east enders ) who is using a special method |
#                                             |
# he learned in Afghanistan to fight off his  |
# he learned in afghanistan to fight off his  |
#                                             |
# opponents . But Jack has a more personal    |
# opponents . but jack has a more personal    |
#                                             |
# reason for taking him down , that draws the |
# reason for taking him down , that draws the |
#                                             |
# two men into an explosive final showdown    |
# two men into an explosive final showdown    |
#                                             |
# where only one will walk away alive .< br   |
# where only one will walk away alive .< br   |
#                                             |
# />< br /> After Until Death , Van Damme     |
# />< br /> after until death , van damme     |
#                                             |
# appeared to be on a high , showing he could |
# appeared to be on a high , showing he could |
#                                             |
# make the best straight to video films in    |
# make the best straight to video films in    |
#                                             |
# the action market . While that was a far    |
# the action market . while that was a far    |
#                                             |
# more drama oriented film , with The         |
# more drama oriented film , with the         |
#                                             |
# Shepherd he has returned to the high -      |
# shepherd he has returned to the high -      |
#                                             |
# kicking , no brainer action that first made |
# kicking , no brainer action that first made |
#                                             |
# him famous and has sadly produced his       | Running Time:            0.2335
# him famous and has sadly produced his       | Query Exceeded:          no
#                                             | Victim Model Queries:    2729
# worst       film since Derailed . It ' s    | Semantic Similarity:     0.9009546
# speculative film since derailed . it ' s    | Grammatical Errors:      93
#                                             | Levenshtein Edit Dista:  69
# nowhere near as bad as that film , but what | Succeed:                 yes
# nowhere near as bad as that film , but what |
#                                             |
# I said still stands .< br />< br /> A dull  |
# i said still stands .< br />< br /> a dull  |
#                                             |
# , predictable film , with very little in    |
# , predictable film , with very little in    |
#                                             |
# the way of any exciting action . What       |
# the way of any exciting action . what       |
#                                             |
# little there is mainly consists of some     |
# little there is mainly consists of some     |
#                                             |
# limp fight      scenes , trying to look     |
# limp engagement scenes , trying to look     |
#                                             |
# cool and trendy with some cheap slo - mo /  |
# cool and trendy with some cheap slo - mo /  |
#                                             |
# sped up effects added to them that sadly    |
# sped up effects added to them that sadly    |
#                                             |
# instead make them look more desperate .     |
# instead make them look more desperate .     |
#                                             |
# Being a Mexican set film , director Isaac   |
# being a mexican set film , director isaac   |
#                                             |
# Florentine has tried to give the film a     |
# florentine has tried to give the film a     |
#                                             |
# Robert Rodriguez / Desperado sort of feel , |
# robert rodriguez / desperado sort of feel , |
#                                             |
# but this only adds to the desperation .< br |
# but this only adds to the desperation .< br |
#                                             |
# />< br /> VD gives a particularly           |
# />< br /> vd gives a particularly           |
#                                             |
# uninspired performance and given he ' s     |
# uninspired performance and given he ' s     |
#                                             |
# never been a Robert De Niro sort of actor , |
# never been a robert de niro sort of actor , |
#                                             |
# that can ' t be good . As the villain ,     |
# that can ' t be good . as the villain ,     |
#                                             |
# Lord shouldn ' t expect to leave the beeb   |
# lord shouldn ' t expect to leave the beeb   |
#                                             |
# anytime soon . He gets little dialogue at   |
# anytime soon . he gets little dialogue at   |
#                                             |
# the beginning as he struggles to muster an  |
# the beginning as he struggles to muster an  |
#                                             |
# American accent but gets mysteriously       |
# american accent but gets mysteriously       |
#                                             |
# better towards the end . All the supporting |
# better towards the end . all the supporting |
#                                             |
# cast are equally bland , and do nothing to  |
# cast are equally bland , and do nothing to  |
#                                             |
# raise the films spirits at all .< br />< br |
# raise the films heart   at all .< br />< br |
#                                             |
# /> This is one shepherd that ' s strayed    |
# /> this is one shepherd that ' s strayed    |
#                                             |
# right from the flock . *                    |
# right from the great . *                    |
#                                             |
# Sample: 5 =====================================================================
# Label: 1 (57.23%) --> 0 (52.30%)            |
#                                             |
# First off let me say , If you haven ' t     |
# first off let me say , if you haven ' t     |
#                                             |
# enjoyed a Van Damme movie since bloodsport  |
# enjoyed a van damme movie since bloodsport  |
#                                             |
# , you probably will not like this movie .   |
# , you probably will not like this movie .   |
#                                             |
# Most of these movies may not have the best  |
# most of these movies may not have the best  |
#                                             |
# plots or best actors but I enjoy these      |
# plots or best actors but i enjoy these      |
#                                             |
# kinds of movies for what they are . This    |
# kinds of movies for what they are . this    |
#                                             |
# movie is much better  than any of the       |
# movie is much serious than any of the       |
#                                             |
# movies the other action guys ( Segal and    |
# movies the other action guys ( segal and    | Running Time:            0.075941
#                                             | Query Exceeded:          no
# Dolph ) have thought about putting out the  | Victim Model Queries:    837
# dolph ) have thought about putting out the  | Semantic Similarity:     0.9826943
#                                             | Grammatical Errors:      33
# past few years . Van Damme is good    in    | Levenshtein Edit Dista:  26
# past few years . van damme is serious in    | Succeed:                 yes
#                                             |
# the movie , the movie is only worth         |
# the movie , the movie is only worth         |
#                                             |
# watching to Van Damme fans . It is not as   |
# watching to van damme fans . it is not as   |
#                                             |
# good as Wake of Death ( which i highly      |
# good as wake of death ( which i highly      |
#                                             |
# recommend to anyone of likes Van Damme ) or |
# recommend to anyone of likes van damme ) or |
#                                             |
# In hell but , in my opinion it ' s worth    |
# in hell but , in my opinion it ' s worth    |
#                                             |
# watching . It has    the same type of feel  |
# watching . it suffer the same type of feel  |
#                                             |
# to it as Nowhere to Run . Good    fun stuff |
# to it as nowhere to run . serious fun stuff |
#                                             |
# !                                           |
# !                                           |
#                                             |
# Sample: 6 =====================================================================
# Label: 0 (61.21%) --> 1 (54.44%)            |
#                                             |
# I had high hopes for this one until they    |
# i had high hopes for this one until they    |
#                                             |
# changed the name to ' The Shepherd : Border |
# changed the name to ' the shepherd : border |
#                                             |
# Patrol , the lamest movie name ever , what  |
# patrol , the lamest movie name ever , what  |
#                                             |
# was wrong with just ' The Shepherd '. This  |
# was wrong with just ' the shepherd '. this  |
#                                             |
# is a by the numbers action flick that tips  |
# is a by the numbers action flick that tips  |
#                                             |
# its hat at many classic Van Damme films .   |
# its hat at many classic van damme films .   |
#                                             |
# There is a nice bit of action in a bar      |
# there is a nice bit of action in a bar      |
#                                             |
# which reminded me of hard target and        |
# which reminded me of hard target and        |
#                                             |
# universal soldier but directed with no      |
# universal soldier but directed with no      |
#                                             |
# intensity or flair which is a shame . There |
# intensity or flair which is a shame . there |
#                                             |
# is one great line about ' being p * ss      |
# is one great line about ' being p * ss      |
#                                             |
# drunk and carrying a rabbit ' and some OK   | Running Time:            0.10138
# drunk and carrying a rabbit ' and some ok   | Query Exceeded:          no
#                                             | Victim Model Queries:    1392
# action scenes let down by the cheapness of  | Semantic Similarity:     0.9623772
# action scenes let down by the cheapness of  | Grammatical Errors:      29
#                                             | Levenshtein Edit Dista:  24
# it all . A lot of the times the dialogue    | Succeed:                 yes
# it all . a lot of the times the dialogue    |
#                                             |
# doesn ' t match the characters mouth and    |
# doesn ' t match the characters mouth and    |
#                                             |
# the stunt men fall down dead a split second |
# the stunt men fall down dead a split second |
#                                             |
# before even being shot . The end fight      |
# before even being shot . the end engagement |
#                                             |
# is one of the better Van Damme fights       |
# is one of the better van damme engagement   |
#                                             |
# except the Director tries to go a bit too   |
# except the director tries to go a bit too   |
#                                             |
# John Woo and fails also introducing         |
# john woo and fails also introducing         |
#                                             |
# flashbacks which no one really cares about  |
# flashbacks which no one really cares about  |
#                                             |
# just gets in the way of the action which is |
# just gets in the way of the action which is |
#                                             |
# the whole point of a van Damme film .< br   |
# the whole point of a van damme film .< br   |
#                                             |
# />< br /> Not good , not bad , just average |
# />< br /> not good , not bad , just average |
#                                             |
# generic action .                            |
# generic action .                            |
#                                             |
# Sample: 7 =====================================================================
# Label: 1 (60.65%) --> 0 (50.57%)            |
#                                             |
# Isaac Florentine has made some of the best  |
# isaac florentine has made some of the best  |
#                                             |
# western Martial Arts action movies ever     |
# western martial arts action movies ever     |
#                                             |
# produced . In particular US Seals 2 , Cold  |
# produced . in particular us seals 2 , cold  |
#                                             |
# Harvest , Special Forces and Undisputed 2   |
# harvest , special forces and undisputed 2   |
#                                             |
# are all action classics . You can tell      |
# are all action classics . you can tell      |
#                                             |
# Isaac has a real passion for the genre and  |
# isaac has a real passion for the genre and  |
# ...
# interview with Helen . There are other      |
# interview with helen . there are other      | Running Time:            0.50779
#                                             | Query Exceeded:          no
# implausibilities . If you were locked in    | Victim Model Queries:    3395
# implausibilities . if you were locked in    | Semantic Similarity:     0.8795659
#                                             | Grammatical Errors:      161
# your house with a madman , but nonetheless  | Levenshtein Edit Dista:  70
# your house with a madman , but nonetheless  | Succeed:                 yes
#                                             |
# left on your own for periods of time ,      |
# left on your own for periods of time ,      |
#                                             |
# couldn ' t you figure out a way to escape ? |
# couldn ' t you figure out a way to escape ? |
#                                             |
# < br />< br /> Ryan , I think , is defeated |
# < br />< br /> ryan , i think , is defeated |
#                                             |
# by the material . It feels like he ' s      |
# by the material . it feels like he ' s      |
#                                             |
# overplaying his hand . His series of tics   |
# overplaying his hand . his series of tics   |
#                                             |
# and spasms and the tightly coiled bursts of |
# and spasms and the tightly coiled bursts of |
#                                             |
# dementia all have a been - there , done -   |
# dementia all have a been - there , done -   |
#                                             |
# that robotic feel to them . At this point   |
# that robotic feel to them . at this point   |
#                                             |
# in his career he ' d probably played this   |
# in his career he ' d probably played this   |
#                                             |
# character , to some degree , ten times and  |
# character , to some degree , ten times and  |
#                                             |
# it shows . We are encouraged to empathize   |
# it shows . we are encouraged to empathize   |
#                                             |
# with Howard ( I didn ' t ) through shown    |
# with howard ( i didn ' t ) through shown    |
#                                             |
# bits of humanity , like him being stopped   |
# bits of humanity , like him being stopped   |
#                                             |
# in his tracks by a music box and his        |
# in his tracks by a music box and his        |
#                                             |
# relating to a group of children who won ' t |
# relating to a group of children who won ' t |
#                                             |
# judge him . Lupino just has to act frazzled |
# judge him . lupino just has to act frazzled |
#                                             |
# and in distress , which she is more than    |
# and in distress , which she is more than    |
#                                             |
# capable of and does . < br />< br /> The    |
# capable of and does . < br />< br /> the    |
#                                             |
# picture had one thing going for it ; what   |
# picture had one thing going for it ; what   |
#                                             |
# would be the eventual resolution of the     |
# would be the eventual resolution of the     |
#                                             |
# conflict   ? So naturally there was a       |
# engagement ? so naturally there was a       |
#                                             |
# disappointing ending that was abrupt and    |
# disappointing ending that was abrupt and    |
#                                             |
# ineffective . < br />< br /> Of slight      |
# ineffective . < br />< br /> of slight      |
#                                             |
# interest was a recurring motif where the    |
# interest was a recurring motif where the    |
#                                             |
# camera would catch Howard ' s reflection (  |
# camera would catch howard ' s reflection (  |
#                                             |
# in mirrors , water , Christmas tree         |
# in mirrors , water , christmas tree         |
#                                             |
# decorations ). This indicated something     |
# decorations ). this indicated something     |
#                                             |
# going on , or about to go on , in his head  |
# going on , or about to go on , in his head  |
#                                             |
# . Horner ( 1953 ' s Vicki ), who made his   |
# . horner ( 1953 ' s vicki ), who made his   |
#                                             |
# reputation in production design , does a    |
# reputation in production design , does a    |
#                                             |
# fine job of making the house feel like a    |
# fine job of making the house feel like a    |
#                                             |
# prison . Credit too , the always reliable   |
# prison . credit too , the always reliable   |
#                                             |
# RKO art department for the work on the      |
# rko art department for the work on the      |
#                                             |
# house . In the end , sub - standard work    |
# house . in the end , sub - standard work    |
#                                             |
# from the principals , who all have much     |
# from the principals , who all have much     |
#                                             |
# better films to their credit . < br />< br  |
# better films to their credit . < br />< br  |
#                                             |
# />* ½ out of 4                              |
# />* ½ out of 4                              |
#                                             |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-84fb7132b8a5> in <cell line: 65>()
#      64
#      65 if __name__ == "__main__":
# ---> 66     main()
#
# <ipython-input-4-84fb7132b8a5> in main()
#      60         # OpenAttack.metric.ModificationRate(),
#      61     ])
# ---> 62     attack_eval.eval(imdb_train, visualize=True)
#      63
#      64
#
# /usr/local/lib/python3.9/dist-packages/OpenAttack/attack_eval/attack_eval.py in eval(self, dataset, total_len, visualize, progress_bar, num_workers, chunk_size)
#     177
#     178         # Begin for
# --> 179         for i, res in enumerate(result_iterator):
#     180             total_inst += 1
#     181             success_inst += int(res["success"])
#
# /usr/local/lib/python3.9/dist-packages/OpenAttack/attack_eval/attack_eval.py in ieval(self, dataset, num_workers, chunk_size)
#     139                 for data in self.__iter_dataset(dataset):
#     140                     yield attack_process(self.attacker, self.victim, data, self.invoke_limit)
# --> 141             for ret in self.__iter_metrics(zip(dataset, result_iter())):
#     142                 yield ret
#     143
#
# /usr/local/lib/python3.9/dist-packages/OpenAttack/attack_eval/attack_eval.py in __iter_metrics(self, iterable_result)
#      98
#      99     def __iter_metrics(self, iterable_result):
# --> 100         for data, result in iterable_result:
#     101             adversarial_sample, attack_time, invoke_times = result
#     102             ret = {
#
# /usr/local/lib/python3.9/dist-packages/OpenAttack/attack_eval/attack_eval.py in result_iter()
#     138             def result_iter():
#     139                 for data in self.__iter_dataset(dataset):
# --> 140                     yield attack_process(self.attacker, self.victim, data, self.invoke_limit)
#     141             for ret in self.__iter_metrics(zip(dataset, result_iter())):
#     142                 yield ret
#
# /usr/local/lib/python3.9/dist-packages/OpenAttack/attack_eval/utils.py in attack_process(attacker, victim, data, limit)
#      16         attack_time = victim.context.attack_time
#      17     except KeyboardInterrupt as e:
# ---> 18         raise e
#      19     except Exception as e:
#      20         logger.exception("Exception when evaluate data %s", data)
#
# /usr/local/lib/python3.9/dist-packages/OpenAttack/attack_eval/utils.py in attack_process(attacker, victim, data, limit)
#       8     victim.set_context(data, limit)
#       9     try:
# ---> 10         adversarial_sample = attacker(victim, data)
#      11         invoke_times = victim.context.invoke
#      12         attack_time = victim.context.attack_time
#
# /usr/local/lib/python3.9/dist-packages/OpenAttack/attackers/classification.py in __call__(self, victim, input_)
#      26             goal = ClassifierGoal( origin_x, targeted=False )
#      27
# ---> 28         adversarial_sample = self.attack(victim, input_["x"], goal)
#      29
#      30         if adversarial_sample is not None:
#
# /usr/local/lib/python3.9/dist-packages/OpenAttack/attackers/pwws/__init__.py in attack(self, victim, sentence, goal)
#      76         x_orig =  list(map(lambda x: x[0], x_orig))
#      77
# ---> 78         S = self.get_saliency(victim, x_orig, goal) # (len(sent), )
#      79         S_softmax = np.exp(S - S.max())
#      80         S_softmax = S_softmax / S_softmax.sum()
#
# /usr/local/lib/python3.9/dist-packages/OpenAttack/attackers/pwws/__init__.py in get_saliency(self, clsf, sent, goal)
#     107             x_hat_raw.append(self.tokenizer.detokenize(x_i_hat))
#     108         x_hat_raw.append(self.tokenizer.detokenize(sent))
# --> 109         res = clsf.get_prob(x_hat_raw)[:, goal.target]
#     110         if not goal.targeted:
#     111             res = res[-1] - res[:-1]
#
# /usr/local/lib/python3.9/dist-packages/OpenAttack/victim/base.py in invoke_wrapper(self, *args, **kwargs)
#      11     def invoke_wrapper(self : Victim, *args, **kwargs):
#      12         cnt = method.invoke_count(*args, **kwargs)
# ---> 13         return self.record_invoke(cnt, func, *args, **kwargs)
#      14
#      15     return invoke_wrapper
#
# /usr/local/lib/python3.9/dist-packages/OpenAttack/victim/base.py in record_invoke(self, cnt, func, *args, **kwargs)
#      61
#      62         # call original function here
# ---> 63         ret = func(self, *args, **kwargs)
#      64
#      65         if need_record:
#
# /usr/local/lib/python3.9/dist-packages/OpenAttack/victim/method.py in wrapper(this, *args, **kwargs)
#       9         def wrapper(this, *args, **kwargs):
#      10             self.before_call(*args, **kwargs)
# ---> 11             ret = func(this, *args, **kwargs)
#      12             self.after_call(ret)
#      13             return ret
#
# <ipython-input-4-84fb7132b8a5> in get_prob(self, input_)
#      26         for sent in input_:
#      27             # SentimentIntensityAnalyzer calculates scores of “neg” and “pos” for each instance
# ---> 28             res = self.analyzer.polarity_scores(sent)
#      29
#      30             # we use 𝑠𝑜𝑐𝑟𝑒_𝑝𝑜𝑠 / (𝑠𝑐𝑜𝑟𝑒_𝑛𝑒𝑔 + 𝑠𝑐𝑜𝑟𝑒_𝑝𝑜𝑠) to represent the probability of positive sentiment
#
# /usr/local/lib/python3.9/dist-packages/vaderSentiment/vaderSentiment.py in polarity_scores(self, text)
#     267                 continue
#     268
# --> 269             sentiments = self.sentiment_valence(valence, sentitext, item, i, sentiments)
#     270
#     271         sentiments = self._but_check(words_and_emoticons, sentiments)
#
# /usr/local/lib/python3.9/dist-packages/vaderSentiment/vaderSentiment.py in sentiment_valence(self, valence, sentitext, item, i, sentiments)
#     312                     valence = self._negation_check(valence, words_and_emoticons, start_i, i)
#     313                     if start_i == 2:
# --> 314                         valence = self._special_idioms_check(valence, words_and_emoticons, i)
#     315
#     316             valence = self._least_check(valence, words_and_emoticons, i)
#
# /usr/local/lib/python3.9/dist-packages/vaderSentiment/vaderSentiment.py in _special_idioms_check(valence, words_and_emoticons, i)
#     345         return sentiments
#     346
# --> 347     @staticmethod
#     348     def _special_idioms_check(valence, words_and_emoticons, i):
#     349         words_and_emoticons_lower = [str(w).lower() for w in words_and_emoticons]
#
# KeyboardInterrupt:

# %%
import OpenAttack as oa
import numpy as np
import datasets
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer


# configure access interface of the customized victim model by extending OpenAttack.Classifier.
class MyClassifier(oa.Classifier):
    def __init__(self):
        # nltk.sentiment.vader.SentimentIntensityAnalyzer is a traditional sentiment classification model.
        nltk.download('vader_lexicon')
        self.model = SentimentIntensityAnalyzer()

    def get_pred(self, input_):
        return self.get_prob(input_).argmax(axis=1)

    # access to the classification probability scores with respect input sentences
    def get_prob(self, input_):
        ret = []
        for sent in input_:
            # SentimentIntensityAnalyzer calculates scores of “neg” and “pos” for each instance
            res = self.model.polarity_scores(sent)

            # we use 𝑠𝑜𝑐𝑟𝑒_𝑝𝑜𝑠 / (𝑠𝑐𝑜𝑟𝑒_𝑛𝑒𝑔 + 𝑠𝑐𝑜𝑟𝑒_𝑝𝑜𝑠) to represent the probability of positive sentiment
            # Adding 10^−6 is a trick to avoid dividing by zero.
            prob = (res["pos"] + 1e-6) / (res["neg"] + res["pos"] + 2e-6)

            ret.append(np.array([1 - prob, prob]))

        # The get_prob method finally returns a np.ndarray of shape (len(input_), 2). See Classifier for detail.
        return np.array(ret)

def dataset_mapping(x):
    return {
        "x": x["sentence"],
        # "x": x["text"],
        "y": 1 if x["label"] > 0.5 else 0,
    }

# load some examples of SST-2 for evaluation
dataset = datasets.load_dataset("sst", split="test[:500]").map(function=dataset_mapping)
# choose the costomized classifier as the victim model
victim = MyClassifier()
# choose PWWS as the attacker and initialize it with default parameters
attacker = oa.attackers.VIPERAttacker()
# prepare for attacking
attack_eval = oa.AttackEval(attacker, victim,metrics = [
        oa.metric.SemanticSimilarity(),
        oa.metric.GrammaticalErrors()]
        )
# launch attacks and print attack results
attack_eval.eval(dataset, visualize=True)
# Out:
# WARNING:datasets.builder:No config specified, defaulting to: sst/default
# WARNING:datasets.builder:Found cached dataset sst (/root/.cache/huggingface/datasets/sst/default/1.0.0/b8a7889ef01c5d3ae8c379b84cc4080f8aad3ac2bc538701cbe0ac6416fb76ff)
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/sst/default/1.0.0/b8a7889ef01c5d3ae8c379b84cc4080f8aad3ac2bc538701cbe0ac6416fb76ff/cache-8abe2d90459d20c6.arrow
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Streaming output truncated to the last 5000 lines.
#                                             | Running Time:            0.032639
#                                             | Query Exceeded:          no
# Gollum ' s ` performance ' is incredible !  | Victim Model Queries:    121
#                                             | Succeed:                 no
#                                             |
# Sample: 74 ====================================================================
# Label: 0 (50.00%) --> Failed!               |
#                                             | Running Time:            0.025245
# If this movie were a book , it would be a   | Query Exceeded:          no
# page - turner , you ca n ' t wait to see    | Victim Model Queries:    121
# what happens next .                         | Succeed:                 no
#                                             |
# Sample: 75 ====================================================================
# Label: 0 (56.78%) --> 1 (100.00%)           |
#                                             | Running Time:            0.00264
# Haneke challenges us to confront the        | Query Exceeded:          no
# Haňêke challenges us to coňfřoňẗ the        | Victim Model Queries:    37
#                                             | Semantic Similarity:     0.3976219
# reality of sexual aberration .              | Grammatical Errors:      6
# řêaᶅiẗy of sêxǔal aberřatioň .              | Succeed:                 yes
#                                             |
# Sample: 76 ====================================================================
# Label: 0 (58.04%) --> 1 (100.00%)           |
#                                             |
# Absorbing and disturbing -- perhaps more    |
# Aḃŝorbiňg ânḑ dîsẗǔrḃiňg -- ṕêřĥapŝ morê    |
#                                             | Running Time:            0.0007429
# disturbing than originally intended -- but  | Query Exceeded:          no
# disturḃîňg than ôřiǵînâᶅly intêňded -- ḃǔt  | Victim Model Queries:    6
#                                             | Semantic Similarity:     0.2399776
# a little clarity would have gone a long way | Grammatical Errors:      15
# a ᶅittᶅe clarity wouᶅḑ hâve gone a loňg way | Succeed:                 yes
#                                             |
# .                                           |
# .                                           |
#                                             |
# Sample: 77 ====================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# It ' s the best film of the year so far ,   | Running Time:            0.0002410
# It ' s thê besẗ ḟîlm of ẗhe year so far ,   | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# the benchmark against which all other Best  | Semantic Similarity:     0.1161262
# tĥê ḃenĉhḿâřk agâînst which all otheř Ḃêst  | Grammatical Errors:      17
#                                             | Succeed:                 yes
# Picture contenders should be measured .     |
# Ṕiĉture ĉontenders ŝhoulḑ bê measuřed .     |
#                                             |
# Sample: 78 ====================================================================
# Label: 1 (85.06%) --> 0 (50.00%)            |
#                                             |
# Painful to watch , but viewers willing to   |
# Paînfǔl tô waẗĉh , bǔt vieweřŝ willing to   |
#                                             | Running Time:            0.0003340
# take a chance will be rewarded with two of  | Query Exceeded:          no
# take a ĉhance will ḃe rewârdêd wiẗh tẘô oḟ  | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.2039575
# the year ' s most accomplished and riveting | Grammatical Errors:      20
# tĥe year ' s moŝt accoḿpᶅiŝhêd and rivêẗing | Succeed:                 yes
#                                             |
# film performances .                         |
# fiᶅm perforḿânĉes .                         |
#                                             |
# Sample: 79 ====================================================================
# Label: 1 (64.80%) --> 0 (50.00%)            |
#                                             |
# This is a startling film that gives you a   |
# Thîs iŝ a ŝtařtling fîlḿ ẗhât ǵiṽes you a   |
#                                             | Running Time:            0.0002825
# fascinating , albeit depressing view of     | Query Exceeded:          no
# fâscinâting , aᶅbeît deprêsŝing view of     | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.2855891
# Iranian rural life close to the Iraqi       | Grammatical Errors:      16
# Îřaniâň rural life cᶅoŝê to thê Iřaqi       | Succeed:                 yes
#                                             |
# border .                                    |
# ḃôrdeř .                                    |
#                                             |
# Sample: 80 ====================================================================
# Label: 0 (50.00%) --> Failed!               |
#                                             | Running Time:            0.015286
# A few artsy flourishes aside , Narc is as   | Query Exceeded:          no
# gritty as a movie gets these days .         | Victim Model Queries:    121
#                                             | Succeed:                 no
#                                             |
# Sample: 81 ====================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# While The Isle is both preposterous and     | Running Time:            0.0002615
# Wĥile Tĥê Îsle iŝ bôẗh přeposẗêrous ând     | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# thoroughly misogynistic , its vistas are    | Semantic Similarity:     0.1105156
# thôrôǔghᶅŷ ḿîŝôǵyňîstic , its ṽistas aře    | Grammatical Errors:      16
#                                             | Succeed:                 yes
# incredibly beautiful to look at .           |
# incrêdiḃᶅŷ ḃeautiful tô look at .           |
#                                             |
# Sample: 82 ====================================================================
# Label: 1 (55.23%) --> 0 (50.00%)            |
#                                             | Running Time:            0.0002427
# Together , Tok and O orchestrate a buoyant  | Query Exceeded:          no
# Ťoǵêtĥeř , Ťoǩ anḑ O ôrcĥeŝẗřate a buoyâňt  | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.3810660
# , darkly funny dance of death .             | Grammatical Errors:      11
# , ḑâřklŷ funnŷ dance of dêâth .             | Succeed:                 yes
#                                             |
# Sample: 83 ====================================================================
# Label: 0 (50.00%) --> Failed!               |
#                                             | Running Time:            0.023309
# In the process , they demonstrate that      | Query Exceeded:          no
# there ' s still a lot of life in Hong Kong  | Victim Model Queries:    121
# cinema .                                    | Succeed:                 no
#                                             |
# Sample: 84 ====================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# Director Kapur is a filmmaker with a real   |
# Diřeĉtôr Kapur is â fiᶅmḿakeř wîth â rêâl   |
#                                             |
# flair for epic landscapes and adventure ,   | Running Time:            0.0002935
# fᶅaîr ḟor eṕiĉ ᶅandŝcapês aňḑ advêntǔrê ,   | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# and this is a better film than his earlier  | Semantic Similarity:     0.2000695
# aňd ẗhis is a beẗteř ḟiᶅḿ ẗhan hiŝ êârlîêr  | Grammatical Errors:      25
#                                             | Succeed:                 yes
# English - language movie , the overpraised  |
# Englîŝh - lanǵǔage moviê , the oṽêřpřaised  |
#                                             |
# Elizabeth .                                 |
# Eliẑâbêẗĥ .                                 |
#                                             |
# Sample: 85 ====================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# The movie is a blast of educational energy  | Running Time:            0.0002711
# Ťhe movie is a ḃlast of edǔĉatîônal êňêrgy  | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# , as bouncy animation and catchy songs      | Semantic Similarity:     0.2403179
# , âs ḃôǔňcy animâtion ând caẗcĥy sôngŝ      | Grammatical Errors:      18
#                                             | Succeed:                 yes
# escort you through the entire 85 minutes .  |
# escorẗ yoǔ thřougĥ tĥe êntirê 85 ḿinǔtes .  |
#                                             |
# Sample: 86 ====================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# A sports movie with action that ' s         | Running Time:            0.0002365
# A ŝpořtŝ movie with acẗioň ẗĥât ' ŝ         | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# exciting on the field and a story you care  | Semantic Similarity:     0.4492913
# excîtiňǵ oň ẗhe fielḑ aňd a story yôu carê  | Grammatical Errors:      14
#                                             | Succeed:                 yes
# about off it .                              |
# aḃôǔt oḟḟ it .                              |
#                                             |
# Sample: 87 ====================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# Doug Liman , the director of Bourne ,       |
# Dôǔǵ Limâň , ẗĥê ḑirêctor ôḟ Ḃourne ,       |
#                                             |
# directs the traffic well , gets a nice      | Running Time:            0.0003390
# dirêĉts the traḟfiĉ weᶅᶅ , ǵêts a ňicê      | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# wintry look from his locations , absorbs us | Semantic Similarity:     0.1053224
# winẗřy ᶅook fřôm hîŝ locâtioňs , âḃsôřbs us | Grammatical Errors:      33
#                                             | Succeed:                 yes
# with the movie ' s spycraft and uses Damon  |
# wiẗĥ the môvie ' s ŝpycraft and usês Daḿôn  |
#                                             |
# ' s ability to be focused and sincere .     |
# ' ŝ âḃility ẗo be fôcused and siňĉêre .     |
#                                             |
# Sample: 88 ====================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             | Running Time:            0.0001383
# The tenderness of the piece is still intact | Query Exceeded:          no
# Thê tenderňess of thê pieĉe is stilᶅ iňẗâct | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.0237906
# .                                           | Grammatical Errors:      7
# .                                           | Succeed:                 yes
#                                             |
# Sample: 89 ====================================================================
# Label: 1 (81.00%) --> 0 (50.00%)            |
#                                             |
# Katz uses archival footage , horrifying     |
# Ǩatz ǔsês arĉĥivaᶅ fôoẗaǵê , horrîḟying     |
#                                             |
# documents of lynchings , still photographs  |
# ḑoĉuments oḟ ᶅyňcĥiňǵs , ŝtiᶅl ṕhoẗôǵřaphs  |
#                                             | Running Time:            0.0002363
# and charming old reel - to - reel           | Query Exceeded:          no
# and cĥarḿiňg oᶅḑ řêel - ẗô - řeeᶅ           | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.1743860
# recordings of Meeropol entertaining his     | Grammatical Errors:      31
# řeĉôřdings ôḟ Ḿeeřôpôl êntêrtâiniňg his     | Succeed:                 yes
#                                             |
# children to create his song history , but   |
# chiᶅdřên to ĉřêâte hîŝ song ĥiŝtôry , but   |
#                                             |
# most powerful of all is the song itself     |
# ḿôst poẘeřfǔᶅ of alᶅ iŝ thê soňg itseᶅḟ     |
#                                             |
# Sample: 90 ====================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# Like the film ' s almost anthropologically  |
# Ĺiǩê ẗhe film ' ŝ almost anthrôpoᶅogicaᶅly  |
#                                             | Running Time:            0.0001843
# detailed realization of early - ' 80s       | Query Exceeded:          no
# ḑeẗaiᶅed řêalîzaẗion of eařly - ' 80s       | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.3942586
# suburbia , it ' s significant without being | Grammatical Errors:      15
# ŝǔbǔrḃîâ , it ' s sîgniḟiĉaňẗ ẘithoǔt beiňǵ | Succeed:                 yes
#                                             |
# overstated .                                |
# ôṽerstateḑ .                                |
#                                             |
# Sample: 91 ====================================================================
# Label: 0 (100.00%) --> Failed!              |
#                                             |
# While McFarlane ' s animation lifts the     | Running Time:            0.01172
# film firmly above the level of other coming | Query Exceeded:          no
# - of - age films ... it ' s also so jarring | Victim Model Queries:    121
# that it ' s hard to get back into the boys  | Succeed:                 no
# ' story .                                   |
#                                             |
# Sample: 92 ====================================================================
# Label: 0 (57.80%) --> 1 (100.00%)           |
#                                             |
# If nothing else , this movie introduces a   | Running Time:            0.0011556
# If nothing elsê , thîs môvie îňtřôduĉes a   | Query Exceeded:          no
#                                             | Victim Model Queries:    19
# promising , unusual kind of psychological   | Semantic Similarity:     0.1904984
# promîsînǵ , ǔňǔsuaᶅ kind ôf psychôlôgicaᶅ   | Grammatical Errors:      12
#                                             | Succeed:                 yes
# horror .                                    |
# hôrrôr .                                    |
#                                             |
# Sample: 93 ====================================================================
# Label: 0 (50.00%) --> Failed!               |
#                                             | Running Time:            0.0094445
# In a normal screen process , these bromides | Query Exceeded:          no
# would be barely enough to sustain an        | Victim Model Queries:    121
# interstitial program on the Discovery       | Succeed:                 no
# Channel .                                   |
#                                             |
# Sample: 94 ====================================================================
# Label: 0 (100.00%) --> Failed!              |
#                                             | Running Time:            0.008985
# But in Imax 3 - D , the clichés disappear   | Query Exceeded:          no
# into the vertiginous perspectives opened up | Victim Model Queries:    121
# by the photography .                        | Succeed:                 no
#                                             |
# Sample: 95 ====================================================================
# Label: 0 (100.00%) --> Failed!              |
#                                             | Running Time:            0.0093968
# Writer - director Burger imaginatively fans | Query Exceeded:          no
# the embers of a dormant national grief and  | Victim Model Queries:    121
# curiosity that has calcified into chronic   | Succeed:                 no
# cynicism and fear .                         |
#                                             |
# Sample: 96 ====================================================================
# Label: 0 (50.00%) --> Failed!               |
#                                             | Running Time:            0.0032959
#                                             | Query Exceeded:          no
# ... a roller - coaster ride of a movie      | Victim Model Queries:    121
#                                             | Succeed:                 no
#                                             |
# Sample: 97 ====================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# I enjoyed Time of Favor while I was         | Running Time:            0.0001612
# Î êňjoyêd Tîme of Ḟavor whiᶅe I wâs         | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# watching it , but I was surprised at how    | Semantic Similarity:     0.0343296
# watĉĥing it , ḃǔt I wâs ŝǔrprîseḑ at hoẘ    | Grammatical Errors:      18
#                                             | Succeed:                 yes
# quickly it faded from my memory .           |
# ʠǔiĉǩly iẗ faḑeḑ froḿ ḿy memôřy .           |
#                                             |
# Sample: 98 ====================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             | Running Time:            0.0003130
# Chicago is sophisticated , brash , sardonic | Query Exceeded:          no
# Ĉhicago is soṕhisẗicated , brâsh , sardonic | Victim Model Queries:    4
#                                             | Semantic Similarity:     0.2641070
# , completely joyful in its execution .      | Grammatical Errors:      11
# , ĉoḿpletely ĵoŷful in îẗŝ eẍecuẗiôn .      | Succeed:                 yes
#                                             |
# Sample: 99 ====================================================================
# Label: 0 (50.00%) --> Failed!               |
#                                             | Running Time:            0.0065567
# Steve Irwin ' s method is Ernest Hemmingway | Query Exceeded:          no
# at accelerated speed and volume .           | Victim Model Queries:    121
#                                             | Succeed:                 no
#                                             |
# Sample: 100 ===================================================================
# Label: 1 (54.37%) --> 0 (50.00%)            |
#                                             |
# A refreshing Korean film about five female  |
# Â řêfreshing Korean film aboǔẗ fîṽê fêmaᶅê  |
#                                             | Running Time:            0.0002115
# high school friends who face an uphill      | Query Exceeded:          no
# hiǵh scĥool frîenḑs wĥo fâce an uṕhiᶅᶅ      | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.3598476
# battle when they try to take their          | Grammatical Errors:      19
# ḃatẗle when theŷ třŷ to take tĥêîř          | Succeed:                 yes
#                                             |
# relationships into deeper waters .          |
# rêlâẗiôňsĥîṕŝ inẗo deeṕeř waẗêrŝ .          |
#                                             |
# Sample: 101 ===================================================================
# Label: 1 (59.17%) --> 0 (100.00%)           |
#                                             |
# On the surface , it ' s a lovers - on - the |
# Ôň the surface , ît ' ŝ â lôṽêrŝ - ôň - the |
#                                             |
# - run crime flick , but it has a lot in     | Running Time:            0.0005052
# - řun crime fliĉk , but it has â ᶅôt îň     | Query Exceeded:          no
#                                             | Victim Model Queries:    4
# common with Piesiewicz ' s and Kieslowski ' | Semantic Similarity:     0.3991273
# ĉommôn wiẗĥ Pieŝiewicẑ ' s ânḑ Kiesᶅôẘŝki ' | Grammatical Errors:      21
#                                             | Succeed:                 yes
# s earlier work , films like The Double Life |
# ŝ earliêr work , filḿs likê Thê Dôǔble Life |
#                                             |
# of Veronique .                              |
# of Vêroniʠǔe .                              |
#                                             |
# Sample: 102 ===================================================================
# Label: 1 (69.78%) --> 0 (100.00%)           |
#                                             |
# The values that have held the Enterprise    |
# Tĥe ṽaᶅues tĥât have held ẗhe Eňẗêrpriŝe    |
#                                             | Running Time:            0.0001979
# crew together through previous adventures   | Query Exceeded:          no
# cřew tôgêtĥer thrôugh previouŝ advenẗures   | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.2141761
# and perils do so again - courage , self -   | Grammatical Errors:      19
# and ṕerîᶅs dô sô aǵaîn - ĉouraǵê , self -   | Succeed:                 yes
#                                             |
# sacrifice and patience under pressure .     |
# sacřiḟîĉe and ṕatîênce undêr pressure .     |
#                                             |
# Sample: 103 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             | Running Time:            0.0001481
# If it ' s possible for a sequel to outshine | Query Exceeded:          no
# If îẗ ' s pôsŝible for a sequeᶅ to ôutshine | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.2888446
# the original , then SL2 does just that .    | Grammatical Errors:      9
# the oriǵinal , then ŜĹ2 dôes just that .    | Succeed:                 yes
#                                             |
# Sample: 104 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# A romantic comedy that operates by the      | Running Time:            0.0001581
# A řomantic cômedŷ thaẗ ôpeřates bŷ ẗĥe      | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# rules of its own self - contained universe  | Semantic Similarity:     0.0648783
# řǔles of îẗs oẘn seᶅf - contained unîveřŝe  | Grammatical Errors:      13
#                                             | Succeed:                 yes
# .                                           |
# .                                           |
#                                             |
# Sample: 105 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# 4 friends , 2 couples , 2000 miles , and    |
# 4 frîendŝ , 2 couplês , 2000 ḿiᶅês , and    |
#                                             | Running Time:            0.0002429
# all the Pabst Blue Ribbon beer they can     | Query Exceeded:          no
# âlᶅ the Paḃst Ḃᶅue Ribbon ḃêer ẗheŷ can     | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.3388645
# drink - it ' s the ultimate redneck road -  | Grammatical Errors:      17
# ḑriňk - it ' ŝ the uᶅtimate řêdneck řôâd -  | Succeed:                 yes
#                                             |
# trip .                                      |
# trip .                                      |
#                                             |
# Sample: 106 ===================================================================
# Label: 1 (62.74%) --> 0 (50.00%)            |
#                                             |
# The film is often filled with a sense of    | Running Time:            0.0002916
# Thê film is often fiᶅled witĥ a sênse ôf    | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# pure wonderment and excitement not often    | Semantic Similarity:     0.4698248
# purê ẘoňderment and eẍciẗement nôẗ often    | Grammatical Errors:      13
#                                             | Succeed:                 yes
# seen in today ' s cinema du sarcasm         |
# seen in toḑay ' ŝ ĉiňema dǔ sâřĉâŝm         |
#                                             |
# Sample: 107 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# It might be tempting to regard Mr . Andrew  |
# Îẗ ḿigĥẗ ḃê teḿpẗing ẗô rêǵârd Ḿr . Ânḑreẘ  |
#                                             |
# and his collaborators as oddballs , but Mr  | Running Time:            0.0002968
# and ĥîŝ ĉôllaḃoraẗors aŝ odḑbâlls , buẗ Mr  | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# . Earnhart ' s quizzical , charming movie   | Semantic Similarity:     0.1554749
# . Eârnĥařt ' s ʠuiẑziĉâᶅ , châřḿing moṽie   | Grammatical Errors:      29
#                                             | Succeed:                 yes
# allows us to see them , finally , as        |
# aᶅlowŝ uŝ to ŝêê tĥêḿ , ḟiňâᶅly , âs        |
#                                             |
# artists .                                   |
# arẗîsẗs .                                   |
#                                             |
# Sample: 108 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             | Running Time:            0.0002263
# A feel - good picture in the best sense of  | Query Exceeded:          no
# A ḟêêl - good pîĉtǔřê in tĥe ḃesẗ sênŝe of  | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.121316
# the term .                                  | Grammatical Errors:      9
# thê ẗêrm .                                  | Succeed:                 yes
#                                             |
# Sample: 109 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# Edited and shot with a syncopated style     |
# Êḑiteḑ ânḑ ŝhot ẘîth a ŝynĉôṕated sẗylê     |
#                                             |
# mimicking the work of his subjects , Pray   | Running Time:            0.0003147
# mîmiĉǩiňǵ ẗhe ẘořk of his sǔbĵects , Ṕřay   | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# turns the idea of the documentary on its    | Semantic Similarity:     0.3190847
# tuřňs tĥe idea of tĥe ḑocumenẗârŷ on îts    | Grammatical Errors:      28
#                                             | Succeed:                 yes
# head , making it rousing , invigorating fun |
# hêad , maǩing iẗ řoǔsîng , inṽigôratiňg fǔn |
#                                             |
# lacking any MTV puffery .                   |
# lacking aňy MTV puffêry .                   |
#                                             |
# Sample: 110 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             | Running Time:            0.0001569
# A mostly intelligent , engrossing and       | Query Exceeded:          no
# A mostᶅy intêlᶅiǵenẗ , eňgrosŝinǵ aňd       | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.1766578
# psychologically resonant suspenser .        | Grammatical Errors:      9
# pŝŷchoᶅogîcâᶅly rêsonant ŝǔŝpênser .        | Succeed:                 yes
#                                             |
# Sample: 111 ===================================================================
# Label: 0 (100.00%) --> Failed!              |
#                                             |
# It ' s this memory - as - identity          | Running Time:            0.011286
# obviation that gives Secret Life its        | Query Exceeded:          no
# intermittent unease , reaffirming that long | Victim Model Queries:    121
# - held illusions are indeed reality , and   | Succeed:                 no
# that erasing them recasts the self .        |
#                                             |
# Sample: 112 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             | Running Time:            0.0002546
# Hip - hop has a history , and it ' s a      | Query Exceeded:          no
# Hip - hôp haŝ a hiŝtorŷ , ând iẗ ' s â      | Victim Model Queries:    4
#                                             | Semantic Similarity:     -0.009361
# metaphor for this love story .              | Grammatical Errors:      11
# ḿetâpĥor for tĥis ᶅovê ŝtorŷ .              | Succeed:                 yes
#                                             |
# Sample: 113 ===================================================================
# Label: 0 (50.00%) --> Failed!               |
#                                             | Running Time:            0.013031
# In scope , ambition and accomplishment ,    | Query Exceeded:          no
# Children of the Century ... takes Kurys '   | Victim Model Queries:    121
# career to a whole new level .               | Succeed:                 no
#                                             |
# Sample: 114 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# This may not have the dramatic gut -        |
# Tĥîŝ may noẗ ĥâvê the ḑramaẗîc gut -        |
#                                             |
# wrenching impact of other Holocaust films , | Running Time:            0.000211
# wreňcĥinǵ îmṕaĉt oḟ oẗĥer Holocaǔst ḟilmŝ , | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# but it ' s a compelling story , mainly      | Semantic Similarity:     0.0305818
# ḃuẗ it ' s â cômṕelling storŷ , maiňly      | Grammatical Errors:      29
#                                             | Succeed:                 yes
# because of the way it ' s told by the       |
# ḃecauŝe ôf tĥê wâŷ it ' s ẗolḑ ḃŷ ẗĥe       |
#                                             |
# people who were there .                     |
# ṕeople ẘhô ẘerê there .                     |
#                                             |
# Sample: 115 ===================================================================
# Label: 0 (50.00%) --> Failed!               |
#                                             | Running Time:            0.0033543
#                                             | Query Exceeded:          no
# Between the drama of Cube ?                 | Victim Model Queries:    121
#                                             | Succeed:                 no
#                                             |
# Sample: 116 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# s personal revelations regarding what the   |
# s ṕerŝonal reṽelâtiôns řeǵarding wĥat tĥe   |
#                                             | Running Time:            0.0001755
# shop means in the big picture , iconic      | Query Exceeded:          no
# shop meanŝ iň ẗhe ḃig ṕîĉtǔre , îconiĉ      | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.1291010
# characters gambol fluidly through the story | Grammatical Errors:      24
# cĥařâcteřs gaḿḃôl ḟluidᶅy ẗĥrough ẗhe sẗory | Succeed:                 yes
#                                             |
# , with charming results .                   |
# , wîth chârḿiňg resǔlts .                   |
#                                             |
# Sample: 117 ===================================================================
# Label: 1 (65.57%) --> 0 (50.00%)            |
#                                             | Running Time:            0.0003369
# A gentle , compassionate drama about grief  | Query Exceeded:          no
# A gêntᶅe , côḿpaŝsîônaẗe drama aḃout ǵrîeḟ  | Victim Model Queries:    4
#                                             | Semantic Similarity:     0.3815611
# and healing .                               | Grammatical Errors:      8
# ând heâling .                               | Succeed:                 yes
#                                             |
# Sample: 118 ===================================================================
# Label: 0 (65.20%) --> 1 (100.00%)           |
#                                             |
# Somewhere short of Tremors on the modern B  |
# Soḿewhêre short ôf Tremors ôn the modeřn Ḃ  |
#                                             | Running Time:            0.0009820
# - scene : neither as funny nor as clever ,  | Query Exceeded:          no
# - ŝĉêne : nêiẗher âs fǔňny ňoř aŝ cleṽeř ,  | Victim Model Queries:    11
#                                             | Semantic Similarity:     0.2956302
# though an agreeably unpretentious way to    | Grammatical Errors:      20
# ẗĥôuǵĥ ân agreeably ǔnpreẗeňẗiôus ẘây to    | Succeed:                 yes
#                                             |
# spend ninety minutes .                      |
# ŝpênd ninêẗy mînutes .                      |
#                                             |
# Sample: 119 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# Digital - video documentary about stand -   | Running Time:            0.0001693
# Diǵîtâᶅ - vidêo ḑocumêntařy abôut sẗanḑ -   | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# up comedians is a great glimpse into a very | Semantic Similarity:     -0.048381
# uṕ coḿêdiâns iŝ a greaẗ ǵlîḿpse intô a veřŷ | Grammatical Errors:      13
#                                             | Succeed:                 yes
# different world .                           |
# dîfḟeřent wořᶅd .                           |
#                                             |
# Sample: 120 ===================================================================
# Label: 0 (50.00%) --> Failed!               |
#                                             | Running Time:            0.011335
# Unlike most teen flicks , Swimming takes    | Query Exceeded:          no
# its time to tell its story , casts mostly   | Victim Model Queries:    121
# little - known performers in key roles ,    | Succeed:                 no
# and introduces some intriguing ambiguity .  |
#                                             |
# Sample: 121 ===================================================================
# Label: 1 (81.77%) --> 0 (50.00%)            |
#                                             |
# An enthralling , playful film that          |
# Ân ênthrâlᶅîng , plâyḟǔl fiᶅm thâẗ          |
#                                             |
# constantly frustrates our desire to know    |
# consẗaňẗᶅy fřusẗřâtes ôǔr dêsîře to knôw    |
#                                             | Running Time:            0.0002480
# the ` truth ' about this man , while        | Query Exceeded:          no
# the ` trǔth ' abôǔt ẗhiŝ mân , wĥiᶅe        | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.0966742
# deconstructing the very format of the       | Grammatical Errors:      33
# decônsẗrǔctîňg tĥe very fôrḿaẗ ôf ẗĥe       | Succeed:                 yes
#                                             |
# biography in a manner that Derrida would    |
# bioǵřaphŷ in a ḿânner tĥaẗ Ďeřridâ ẘôuᶅḑ    |
#                                             |
# doubtless give his blessing to .            |
# douḃẗleŝs ǵîṽe ĥis ḃlessing to .            |
#                                             |
# Sample: 122 ===================================================================
# Label: 1 (55.50%) --> 0 (50.00%)            |
#                                             |
# It ' s obviously struck a responsive chord  | Running Time:            0.0002306
# It ' s obvîously ŝẗruck a resṕoňsive ĉĥord  | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# with many South Koreans , and should work   | Semantic Similarity:     0.1202945
# wîẗĥ ḿâny Ŝoutĥ Ǩořeâňs , anḑ ŝhôuᶅd worǩ   | Grammatical Errors:      19
# ...
#                                             | Semantic Similarity:     0.0969669
# always interesting , and those are reasons  | Grammatical Errors:      24
# âᶅẘays iňẗereŝtiňǵ , aňd thôŝe âre řeâsôňŝ  | Succeed:                 yes
#                                             |
# enough to see it .                          |
# enouǵh to ŝee iẗ .                          |
#                                             |
# Sample: 486 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# The film runs on equal parts of innocence   | Running Time:            0.0001645
# The ḟiᶅm runŝ on equaᶅ parts ôf inňôceňcê   | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# and wisdom -- wisdom that comes with        | Semantic Similarity:     -0.122881
# aňd wisdôm -- wîsdoḿ that comês ẘitĥ        | Grammatical Errors:      12
#                                             | Succeed:                 yes
# experience .                                |
# expeřiênce .                                |
#                                             |
# Sample: 487 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             | Running Time:            0.0001566
#                                             | Query Exceeded:          no
# It has fun being grown up .                 | Victim Model Queries:    3
# Iẗ ĥas ḟun ḃeîňg ǵroẘn up .                 | Semantic Similarity:     -0.067617
#                                             | Grammatical Errors:      6
#                                             | Succeed:                 yes
#                                             |
# Sample: 488 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             | Running Time:            0.0002167
# Like old myths and wonder tales spun afresh | Query Exceeded:          no
# Likê ôld myths anḑ ẘoňdeř taᶅes spuň aḟřêsh | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.3823028
# .                                           | Grammatical Errors:      8
# .                                           | Succeed:                 yes
#                                             |
# Sample: 489 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# Rarely do films come along that are as      | Running Time:            0.0001833
# Rarely dô fîlms come aᶅônǵ that aře as      | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# intelligent , exuberant , and moving as     | Semantic Similarity:     0.4021490
# intelligênẗ , exuberânt , anḑ movîng aŝ     | Grammatical Errors:      14
#                                             | Succeed:                 yes
# Monsoon Wedding .                           |
# Mônsôôn Ŵeḑdinǵ .                           |
#                                             |
# Sample: 490 ===================================================================
# Label: 1 (54.29%) --> 0 (50.00%)            |
#                                             | Running Time:            0.0001800
# One scarcely needs the subtitles to enjoy   | Query Exceeded:          no
# One scarĉêᶅy nêeḑs the ŝuḃẗitles to enjôy   | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.0867833
# this colorful action farce .                | Grammatical Errors:      9
# tĥis côlôrḟul âction fařce .                | Succeed:                 yes
#                                             |
# Sample: 491 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             | Running Time:            0.0001550
#                                             | Query Exceeded:          no
# Quite funny for the type of movie it is ... | Victim Model Queries:    4
# Quite ḟunňy fôr ẗĥê tyṕe ôḟ moṽîê ît iŝ ... | Semantic Similarity:     0.0968415
#                                             | Grammatical Errors:      8
#                                             | Succeed:                 yes
#                                             |
# Sample: 492 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# It ' s often infuriatingly glib and         |
# It ' s often iňfurîaẗiňgly glib and         |
#                                             |
# posturing , and yet it has been made with   |
# pôŝturiňg , and ŷet iẗ has ḃeên mâde with   |
#                                             | Running Time:            0.0001986
# great evident care and manages to deliver   | Query Exceeded:          no
# greâẗ evideňt câře aňd mânages to ḑeᶅivêr   | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.3843709
# up the man in a way to arouse further       | Grammatical Errors:      25
# uṕ tĥe man in a wâŷ to âřouŝê ḟǔrthêr       | Succeed:                 yes
#                                             |
# curiosity in even the most unknowing viewer |
# ĉǔrîoŝîẗy in evên ẗhe most unǩnôwiňg vîewêr |
#                                             |
# .                                           |
# .                                           |
#                                             |
# Sample: 493 ===================================================================
# Label: 0 (100.00%) --> 1 (100.00%)          |
#                                             | Running Time:            0.0001419
# One of ( Herzog ' s ) least inspired works  | Query Exceeded:          no
# Ôňe oḟ ( Herzoǵ ' s ) leasẗ inspired workŝ  | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.2701595
# .                                           | Grammatical Errors:      8
# .                                           | Succeed:                 yes
#                                             |
# Sample: 494 ===================================================================
# Label: 0 (81.86%) --> 1 (100.00%)           |
#                                             |
# This boisterous comedy serves up a cruel    |
# Ťhis boisteřouŝ comedy ŝeřṽeŝ ǔp a cruêl    |
#                                             | Running Time:            0.0002985
# reminder of the fate of hundreds of         | Query Exceeded:          no
# remînḑer of ẗhê fate ôf huňḑreds ôḟ         | Victim Model Queries:    4
#                                             | Semantic Similarity:     0.3455708
# thousands of Chinese , one which can only   | Grammatical Errors:      20
# ẗhoǔsanḑŝ of Cĥînêse , ônê whicĥ can only   | Succeed:                 yes
#                                             |
# qualify as a terrible tragedy .             |
# qǔaᶅify as a ẗeřrîblê ẗrâgedy .             |
#                                             |
# Sample: 495 ===================================================================
# Label: 1 (60.00%) --> 0 (50.00%)            |
#                                             |
# Elling really is about a couple of crazy    | Running Time:            0.0002553
# Êlᶅing really îs aḃôut a couṕle of ĉrâzy    | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# guys , and it ' s therapeutic to laugh      | Semantic Similarity:     0.1615297
# ǵuŷs , ânḑ it ' s tĥerapêǔẗic to lâugh      | Grammatical Errors:      15
#                                             | Succeed:                 yes
# along with them .                           |
# âloňg wiẗh ẗĥem .                           |
#                                             |
# Sample: 496 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             | Running Time:            0.0001669
# An irresistible combination of a rousing    | Query Exceeded:          no
# An îřrêŝisẗîble ĉomḃinatioň ôḟ a rouŝîňg    | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.2639284
# good story set on a truly grand scale .     | Grammatical Errors:      12
# ǵooḑ stôrŷ sêt on a ẗrǔlŷ grâňd ŝcâle .     | Succeed:                 yes
#                                             |
# Sample: 497 ===================================================================
# Label: 0 (52.30%) --> 1 (100.00%)           |
#                                             |
# There ' s no denying the physically         |
# Theřê ' s ňo denŷing tĥe phyŝically         |
#                                             | Running Time:            0.0013113
# spectacular qualities of the film ... or    | Query Exceeded:          no
# ŝpectâcular qualitiês of tĥê ḟiᶅm ... oř    | Victim Model Queries:    19
#                                             | Semantic Similarity:     0.1955433
# the emotional integrity of the performances | Grammatical Errors:      15
# thê êḿôtionâl integrity of ẗhe performanceŝ | Succeed:                 yes
#                                             |
# .                                           |
# .                                           |
#                                             |
# Sample: 498 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             | Running Time:            0.0001578
# Few films this year have been as resolute   | Query Exceeded:          no
# Fêw ḟilms thîs yeâr haṽe beên aŝ řeŝolǔte   | Victim Model Queries:    3
#                                             | Semantic Similarity:     0.0865822
# in their emotional nakedness .              | Grammatical Errors:      12
# in theîr eḿôẗiôňal ňâkeḑnesŝ .              | Succeed:                 yes
#                                             |
# Sample: 499 ===================================================================
# Label: 1 (100.00%) --> 0 (50.00%)           |
#                                             |
# Exquisitely acted and masterfully if        |
# Exʠuisîtely acted and ḿastêrfulᶅy iḟ        |
#                                             |
# preciously interwoven ... ( the film )      | Running Time:            0.0012867
# přeciôusly intêrẘôṽên ... ( thê film )      | Query Exceeded:          no
#                                             | Victim Model Queries:    3
# addresses in a fascinating , intelligent    | Semantic Similarity:     0.2580443
# addrêsŝes iň a fâsĉinatînǵ , întelᶅîǵênẗ    | Grammatical Errors:      22
#                                             | Succeed:                 yes
# manner the intermingling of race , politics |
# mannêř thê inteřḿinǵlîňg of řacê , pôᶅiẗîcŝ |
#                                             |
# and local commerce .                        |
# and ᶅocal comḿeřĉe .                        |
#                                             |
# Sample: 500 ===================================================================
# Label: 0 (54.29%) --> 1 (100.00%)           |
#                                             |
# Stevenson ' s performance is at once        | Running Time:            0.0022807
# Stevênŝôň ' s ṕerfôřmanĉe is at once        | Query Exceeded:          no
#                                             | Victim Model Queries:    35
# clueless and fiercely committed , a         | Semantic Similarity:     0.4251543
# cᶅuelêss and fîeřĉely committed , a         | Grammatical Errors:      9
#                                             | Succeed:                 yes
# volatile combination .                      |
# ṽôᶅatîᶅe ĉoḿbiňation .                      |
#                                             |
# +========================================+
# |                Summary                 |
# +========================================+
# | Total Attacked Instances:  | 500       |
# | Successful Instances:      | 403       |
# | Attack Success Rate:       | 0.806     |
# | Avg. Running Time:         | 0.0022349 |
# | Total Query Exceeded:      | 0         |
# | Avg. Victim Model Queries: | 27.456    |
# | Avg. Semantic Similarity:  | 0.2018    |
# | Avg. Grammatical Errors:   | 15.533    |
# +========================================+
# {'Total Attacked Instances': 500,
#  'Successful Instances': 403,
#  'Attack Success Rate': 0.806,
#  'Avg. Running Time': 0.002234895706176758,
#  'Total Query Exceeded': 0.0,
#  'Avg. Victim Model Queries': 27.456,
#  'Avg. Semantic Similarity': 0.20180348603666712,
#  'Avg. Grammatical Errors': 15.53349875930521}

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import OpenAttack as oa
import numpy as np
import datasets
import sentencepiece as spm


def dataset_mapping(x):
    return {
        "x": x["sentence"],
        #"x": x["text"],
        "y": 1 if x["label"] > 0.5 else 0,
        # "y": x["label"],
    }

def main():
    # 从 datasets 库中加载 IMDB 数据集的前 2000 个样本
    imdb_train = datasets.load_dataset("sst", split="train[:100]").map(function=dataset_mapping)

    victim = oa.DataManager.loadVictim("BERT.SST").to("cuda:0")
    #victim = oa.DataManager.loadVictim("ALBERT.IMDB").to("cuda:0")


    # 选择 Deepwordbug 作为攻击者并使用默认参数初始化
    attacker = oa.attackers.DeepWordBugAttacker() # 修改此行
    #attacker = oa.attackers.TextBuggerAttacker()

    # 准备进行攻击
    """attack_eval = oa.AttackEval(attacker, victim, metrics = [
        # oa.metric.SemanticSimilarity(),
        # oa.metric.GrammaticalErrors(),
        # OpenAttack.metric.Fluency()
        # OpenAttack.metric.EditDistance(),
        oa.metric.ModificationRate(),
    ])"""
    attack_eval = oa.AttackEval(attacker, victim)

    # 发起攻击并打印攻击结果
    # attack_eval.eval(imdb_train, visualize=True,num_workers=2)
    attack_eval.eval(imdb_train, visualize=True)

if __name__ == "__main__":
    main()
# Out:
# WARNING:datasets.builder:No config specified, defaulting to: sst/default
# WARNING:datasets.builder:Found cached dataset sst (/root/.cache/huggingface/datasets/sst/default/1.0.0/b8a7889ef01c5d3ae8c379b84cc4080f8aad3ac2bc538701cbe0ac6416fb76ff)
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/sst/default/1.0.0/b8a7889ef01c5d3ae8c379b84cc4080f8aad3ac2bc538701cbe0ac6416fb76ff/cache-ee1d1c8ae6622e4f.arrow
# Sample: 1 =====================================================================
# Label: 1 (98.17%) --> Failed!               |
#                                             |
# The Rock is destined to be the 21st Century | Running Time:            0.0016472
# ' s new `` Conan '' and that he ' s going   | Query Exceeded:          no
# to make a splash even greater than Arnold   | Victim Model Queries:    42
# Schwarzenegger , Jean - Claud Van Damme or  | Succeed:                 no
# Steven Segal .                              |
#                                             |
# Sample: 2 =====================================================================
# Label: 1 (99.30%) --> 0 (65.90%)            |
#                                             |
# The gorgeously elaborate continuation of `` |
# The gorgeouѕly elaborate continuation of `` |
#                                             |
# The Lord of the Rings '' trilogy is so huge |
# The Lord of the Rings '' trilоgy іs so huge |
#                                             |
# that a column of words can not adequately   | Running Time:            0.0019076
# that a column of words can not adequately   | Query Exceeded:          no
#                                             | Victim Model Queries:    53
# describe co - writer \/ director Peter      | Succeed:                 yes
# describе ϲo - writer \/ director Peter      |
#                                             |
# Jackson ' s expanded vision of J . R . R .  |
# Jackson ' s expanded vision of J . R . R .  |
#                                             |
# Tolkien ' s Middle - earth .                |
# Tolkien ' s Middle - earth .                |
#                                             |
# Sample: 3 =====================================================================
# Label: 1 (87.19%) --> 0 (96.67%)            |
#                                             |
# Singer \/ composer Bryan Adams contributes  |
# Singer \/ composer Bryan Adams contributes  |
#                                             |
# a slew of songs -- a few potential hits , a |
# a slew of songs -- a few potential hits , a | Running Time:            0.001601
#                                             | Query Exceeded:          no
# few more simply intrusive to the story --   | Victim Model Queries:    44
# few more simply intrusive to the story --   | Succeed:                 yes
#                                             |
# but the whole package certainly captures    |
# but the whole pac𝒌age certaiոly caрtures    |
#                                             |
# the intended , er , spirit of the piece .   |
# the intended , er , spіrit of tհe piece .   |
#                                             |
# Sample: 4 =====================================================================
# Label: 0 (84.86%) --> Failed!               |
#                                             | Running Time:            0.0010304
# You ' d think by now America would have had | Query Exceeded:          no
# enough of plucky British eccentrics with    | Victim Model Queries:    22
# hearts of gold .                            | Succeed:                 no
#                                             |
# Sample: 5 =====================================================================
# Label: 1 (99.63%) --> 0 (66.76%)            |
#                                             | Running Time:            0.0007091
# Yet the act is still charming here .        | Query Exceeded:          no
# Yet the act iѕ ѕtill charminɡ here .        | Victim Model Queries:    11
#                                             | Succeed:                 yes
#                                             |
# Sample: 6 =====================================================================
# Label: 1 (99.73%) --> Failed!               |
#                                             | Running Time:            0.0017624
# Whether or not you ' re enlightened by any  | Query Exceeded:          no
# of Derrida ' s lectures on `` the other ''  | Victim Model Queries:    36
# and `` the self , '' Derrida is an          | Succeed:                 no
# undeniably fascinating and playful fellow . |
#                                             |
# Sample: 7 =====================================================================
# Label: 1 (99.27%) --> 0 (89.22%)            |
#                                             |
# Just the labour involved in creating the    |
# Just the labour involved in creating the    |
#                                             |
# layered richness of the imagery in this     | Running Time:            0.0013826
# lɑyered richneѕs of the imagery in this     | Query Exceeded:          no
#                                             | Victim Model Queries:    25
# chiaroscuro of madness and light is         | Succeed:                 yes
# chiaroscuro of madness and light iѕ         |
#                                             |
# astonishing .                               |
# astoոishing .                               |
#                                             |
# Sample: 8 =====================================================================
# Label: 1 (99.57%) --> 0 (55.78%)            |
#                                             |
# Part of the charm of Satin Rouge is that it |
# Part of the ϲharm of Satin Rouge іs that it | Running Time:            0.0010424
#                                             | Query Exceeded:          no
# avoids the obvious with humour  and         | Victim Model Queries:    21
# avoids the obѵious wi𝚝h huｍour and         | Succeed:                 yes
#                                             |
# lightness .                                 |
# lightness .                                 |
#                                             |
# Sample: 9 =====================================================================
# Label: 1 (91.95%) --> 0 (87.65%)            |
#                                             |
# a screenplay more ingeniously constructed   | Running Time:            0.0005934
# ɑ screeոplay more ingeniouѕly constructed   | Query Exceeded:          no
#                                             | Victim Model Queries:    12
# than `` Memento ''                          | Succeed:                 yes
# tհan `` Memеnto ''                          |
#                                             |
# Sample: 10 ====================================================================
# Label: 1 (96.40%) --> 0 (75.24%)            |
#                                             | Running Time:            0.0006096
# `` Extreme Ops '' exceeds expectations .    | Query Exceeded:          no
# `` Extreme Oрs '` еxceeds expectatiоns .    | Victim Model Queries:    10
#                                             | Succeed:                 yes
#                                             |
# Sample: 11 ====================================================================
# Label: 1 (99.74%) --> Failed!               |
#                                             | Running Time:            0.0009902
# Good fun , good action , good acting , good | Query Exceeded:          no
# dialogue , good pace , good cinematography  | Victim Model Queries:    20
# .                                           | Succeed:                 no
#                                             |
# Sample: 12 ====================================================================
# Label: 1 (58.80%) --> 0 (88.19%)            |
#                                             |
# You Should Pay Nine Bucks for This :        |
# You Should Pay Nine Bucks for This :        |
#                                             |
# Because you can hear about suffering Afghan | Running Time:            0.0009260
# Because you can heɑr abоut suffering Afghan | Query Exceeded:          no
#                                             | Victim Model Queries:    27
# refugees on the news and still be           | Succeed:                 yes
# refugees on 𝚝he nеws and still be           |
#                                             |
# unaffected .                                |
# unaffec𝚝ed .                                |
#                                             |
# Sample: 13 ====================================================================
# Label: 1 (98.15%) --> 0 (78.49%)            |
#                                             | Running Time:            0.0006316
# Dramas like this make it human .            | Query Exceeded:          no
# Dramɑs like this makе i𝚝 հuman .            | Victim Model Queries:    10
#                                             | Succeed:                 yes
#                                             |
# Sample: 14 ====================================================================
# Label: 0 (95.55%) --> Failed!               |
#                                             | Running Time:            0.0010538
# A thunderous ride at first , quiet cadences | Query Exceeded:          no
# of pure finesse are few and far between ;   | Victim Model Queries:    29
# their shortage dilutes the potency of       | Succeed:                 no
# otherwise respectable action .              |
#                                             |
# Sample: 15 ====================================================================
# Label: 1 (99.80%) --> 0 (52.80%)            |
#                                             |
# Still , this flick is fun , and host to     | Running Time:            0.0007741
# Still , this flick iѕ fսn , and host to     | Query Exceeded:          no
#                                             | Victim Model Queries:    18
# some         truly excellent sequences .    | Succeed:                 yes
# some trulу e ×     cellent   sequences .    |
#                                             |
# Sample: 16 ====================================================================
# Label: 1 (99.79%) --> 0 (79.35%)            |
#                                             |
# Australian actor \/ director John Polson    |
# Australian actor \/ director John Polson    |
#                                             |
# and award - winning English cinematographer |
# and award - winning English cinematographer | Running Time:            0.0010848
#                                             | Query Exceeded:          no
# Giles Nuttgens make a terrific effort at    | Victim Model Queries:    30
# Giles Nuttgens make a terrifіc effort a𝚝    | Succeed:                 yes
#                                             |
# disguising the obvious with energy and      |
# disguising the obѵious wіth energy aոd      |
#                                             |
# innovation .                                |
# innovation .                                |
#                                             |
# Sample: 17 ====================================================================
# Label: 1 (97.57%) --> 0 (82.70%)            |
#                                             |
# You walk out of The Good Girl with mixed    |
# Yoս walk out of The Good Girl with mixed    |
#                                             |
# emotions -- disapproval of Justine combined | Running Time:            0.0009797
# emotions -- disapproval of Justine combined | Query Exceeded:          no
#                                             | Victim Model Queries:    27
# with a tinge of understanding for her       | Succeed:                 yes
# with ɑ tinɡe o𝚏 understandiոg for her       |
#                                             |
# actions .                                   |
# actions .                                   |
#                                             |
# Sample: 18 ====================================================================
# Label: 0 (96.38%) --> Failed!               |
#                                             | Running Time:            0.0008681
# Post 9 \/ 11 the philosophical message of   | Query Exceeded:          no
# `` Personal Freedom First '' might not be   | Victim Model Queries:    23
# as palatable as intended .                  | Succeed:                 no
#                                             |
# Sample: 19 ====================================================================
# Label: 1 (99.85%) --> Failed!               |
#                                             | Running Time:            0.0006015
#                                             | Query Exceeded:          no
# Absorbing character study by André Turpin . | Victim Model Queries:    9
#                                             | Succeed:                 no
#                                             |
# Sample: 20 ====================================================================
# Label: 1 (96.35%) --> 0 (78.39%)            |
#                                             |
# If you love reading and \/ or poetry , then | Running Time:            0.0007594
# If you loѵe reading and \/ or poetry , then | Query Exceeded:          no
#                                             | Victim Model Queries:    20
# by all means check it out .                 | Succeed:                 yes
# by ɑll means cհeck іt ou𝚝 .                 |
#                                             |
# Sample: 21 ====================================================================
# Label: 1 (99.57%) --> 0 (60.51%)            |
#                                             | Running Time:            0.0006073
# You ' ll probably love it .                 | Query Exceeded:          no
# You ` ll probably ⅼove i𝚝 .                 | Victim Model Queries:    10
#                                             | Succeed:                 yes
#                                             |
# Sample: 22 ====================================================================
# Label: 1 (55.90%) --> 0 (88.96%)            |
#                                             |
# `` Frailty '' has been written so well ,    | Running Time:            0.0007818
# `` Frailty '' hɑs beеn writtеn sо weⅼl ,    | Query Exceeded:          no
#                                             | Victim Model Queries:    20
# that even a simple `` Goddammit ! ''        | Succeed:                 yes
# that even a simple `` Goddammit ! ''        |
#                                             |
# Sample: 23 ====================================================================
# Label: 0 (87.29%) --> Failed!               |
#                                             | Running Time:            0.0006282
# near the end takes on a whole other meaning | Query Exceeded:          no
# .                                           | Victim Model Queries:    12
#                                             | Succeed:                 no
#                                             |
# Sample: 24 ====================================================================
# Label: 1 (99.78%) --> 0 (63.39%)            |
#                                             |
# Grenier is terrific , bringing an unforced  |
# Grenier is terri𝚏ic , bringiոg an unforced  |
#                                             |
# , rapid - fire delivery to Toback ' s       | Running Time:            0.0009358
# , raрid - fire delivery to Toback ` ѕ       | Query Exceeded:          no
#                                             | Victim Model Queries:    27
# Heidegger - and Nietzsche - referencing     | Succeed:                 yes
# Heidegger - and Nietzsche - referencing     |
#                                             |
# dialogue .                                  |
# dialogue .                                  |
#                                             |
# Sample: 25 ====================================================================
# Label: 0 (53.24%) --> 1 (64.83%)            |
#                                             |
# The Sundance Film Festival has become so    |
# The Sundance Film Festival has become so    |
#                                             |
# buzz - obsessed that fans and producers     | Running Time:            0.0011029
# buzz - obsеssed 𝚝hat fans and producers     | Query Exceeded:          no
#                                             | Victim Model Queries:    30
# descend upon Utah each January to ferret    | Succeed:                 yes
# descend upon Utah each January tо ferre𝚝    |
#                                             |
# out The Next Great Thing .                  |
# оut The Next Great Thing .                  |
#                                             |
# Sample: 26 ====================================================================
# Label: 0 (56.22%) --> 1 (89.09%)            |
#                                             |
# ` Tadpole ' was one of the films so         |
# ` Tadpole ' waѕ one of the films so         | Running Time:            0.0012407
#                                             | Query Exceeded:          no
# declared this year , but it ' s really more | Victim Model Queries:    29
# declared this year , bսt it ' s reɑlly more | Succeed:                 yes
#                                             |
# of The Next Pretty Good Thing .             |
# o𝚏 The Nеxt Pretty Good Thing .             |
#                                             |
# Sample: 27 ====================================================================
# Label: 1 (99.79%) --> 0 (60.10%)            |
#                                             | Running Time:            0.0006604
# The actors are  fantastic .                 | Query Exceeded:          no
# The aϲtors aⲅe fantas𝚝ic .                 | Victim Model Queries:    8
#                                             | Succeed:                 yes
#                                             |
# Sample: 28 ====================================================================
# Label: 1 (99.70%) --> Failed!               |
#                                             | Running Time:            0.0008628
# They are what makes it worth the trip to    | Query Exceeded:          no
# the theatre .                               | Victim Model Queries:    14
#                                             | Succeed:                 no
#                                             |
# Sample: 29 ====================================================================
# Label: 1 (96.33%) --> 0 (64.41%)            |
#                                             |
# ( Taymor ) utilizes the idea of making      |
# ( Taymor ) utilizes the idea of making      |
#                                             |
# Kahlo ' s art a living , breathing part of  | Running Time:            0.0016093
# Kahlo ' s art a living , brea𝚝hing part of  | Query Exceeded:          no
#                                             | Victim Model Queries:    33
# the movie , often catapulting the artist    | Succeed:                 yes
# the movie , often catapսlting the artis𝚝    |
#                                             |
# into her own work .                         |
# into հer own work .                         |
#                                             |
# Sample: 30 ====================================================================
# Label: 0 (93.75%) --> Failed!               |
#                                             | Running Time:            0.0008707
#                                             | Query Exceeded:          no
# This is n ' t a new idea .                  | Victim Model Queries:    11
#                                             | Succeed:                 no
#                                             |
# Sample: 31 ====================================================================
# Label: 1 (95.38%) --> 0 (91.33%)            |
#                                             |
# It ' s been done before  but never so       | Running Time:            0.0009854
# It ' s bеen done befoⲅe bu𝚝 never so       | Query Exceeded:          no
#                                             | Victim Model Queries:    19
# vividly or with so much passion .           | Succeed:                 yes
# viviԁly or with so much pɑssion .           |
#                                             |
# Sample: 32 ====================================================================
# Label: 1 (99.77%) --> Failed!               |
#                                             |
# ( `` Take Care of My Cat '' ) is an         | Running Time:            0.0014899
# honestly nice little film that takes us on  | Query Exceeded:          no
# an examination of young adult life in urban | Victim Model Queries:    41
# South Korea through the hearts and minds of | Succeed:                 no
# the five principals .                       |
#                                             |
# Sample: 33 ====================================================================
# Label: 1 (92.60%) --> 0 (93.69%)            |
#                                             |
# It ' s not life - affirming -- its vulgar   | Running Time:            0.0007784
# It ' s not li𝚏e - affirming ˗-  its vulgar   | Query Exceeded:          no
#                                             | Victim Model Queries:    21
# and mean , but I liked it .                 | Succeed:                 yes
# and mean , bu𝚝 I likеd іt .                 |
#                                             |
# Sample: 34 ====================================================================
# Label: 1 (96.39%) --> 0 (96.75%)            |
#                                             |
# What `` Empire '' lacks in depth it makes   | Running Time:            0.0007918
# Whɑt `` Emрire '' lacks in depth it ｍakes  | Query Exceeded:          no
#                                             | Victim Model Queries:    18
# up for with its heart  .                    | Succeed:                 yes
# սp for with its heaⲅt .                    |
#                                             |
# Sample: 35 ====================================================================
# Label: 1 (99.63%) --> 0 (78.72%)            |
#                                             |
# Light , silly , photographed with colour    | Running Time:            0.0007393
# Light , silly , photographed with ϲolour    | Query Exceeded:          no
#                                             | Victim Model Queries:    19
# and depth , and rather a good time .        | Succeed:                 yes
# and depth , aոd rather ɑ gоod 𝚝ime .        |
#                                             |
# Sample: 36 ====================================================================
# Label: 1 (97.26%) --> 0 (93.95%)            |
#                                             |
# But tongue - in - cheek preposterousness    |
# Bսt tongue - in - cheek preposterousness    |
#                                             |
# has always been part of For the most  part  |
# has always been part of For the ｍost part  | Running Time:            0.0014472
#                                             | Query Exceeded:          no
# Wilde ' s droll whimsy helps `` Being       | Victim Model Queries:    39
# Wilde ' ѕ droll whimsy helpѕ `` Being       | Succeed:                 yes
#                                             |
# Earnest '' overcome its weaknesses and      |
# Earnest '' ovеrcome its weaknesses and      |
#                                             |
# Parker ' s creative interference ...        |
# Parker ' s creative interference ...        |
#                                             |
# Sample: 37 ====================================================================
# Label: 1 (99.59%) --> 0 (94.10%)            |
#                                             |
# Much of the movie ' s charm  lies in the    | Running Time:            0.0007668
# Much of the movie ' s charｍ liеs іn thе    | Query Exceeded:          no
#                                             | Victim Model Queries:    20
# utter cuteness of Stuart and Margolo .      | Succeed:                 yes
# utter cutenеss of Stuart and Margolo .      |
#                                             |
# Sample: 38 ====================================================================
# Label: 1 (99.52%) --> 0 (86.64%)            |
#                                             |
# Their computer - animated faces are         | Running Time:            0.0006471
# Tհeir computer - anima𝚝ed fɑces are vеry e  | Query Exceeded:          no
#                                             | Victim Model Queries:    12
# very expressive .                           | Succeed:                 yes
# ×    pressive   .                           |
#                                             |
# Sample: 39 ====================================================================
# Label: 0 (91.92%) --> Failed!               |
#                                             |
# The path Ice Age follows most closely ,     | Running Time:            0.0015194
# though , is the one established by Warner   | Query Exceeded:          no
# Bros . giant Chuck Jones , who died a       | Victim Model Queries:    37
# matter of weeks before the movie ' s        | Succeed:                 no
# release .                                   |
#                                             |
# Sample: 40 ====================================================================
# Label: 1 (98.54%) --> 0 (71.09%)            |
#                                             |
# ... spiced with humor  ( ' I speak fluent   |
# ... spiced with huｍor ( ' I speak fluent   |
#                                             |
# flatula , ' advises Denlopp after a rather  |
# flatula , ' advises Denlopp after a rather  |
#                                             |
# , er , bubbly exchange with an alien        |
# , er , bubbly exchange with an alien        | Running Time:            0.0022063
#                                             | Query Exceeded:          no
# deckhand ) and witty updatings ( Silver ' s | Victim Model Queries:    55
# deckhand ) anԁ wіtty updatings ( Silver ' s | Succeed:                 yes
#                                             |
# parrot has been replaced with Morph , a     |
# parrot has been replaced with Morph , a     |
#                                             |
# cute alien creature who mimics everyone and |
# cute alien creature who mimics everyone and |
#                                             |
# everything around )                         |
# everything around )                         |
#                                             |
# Sample: 41 ====================================================================
# Label: 1 (99.46%) --> 0 (62.66%)            |
#                                             | Running Time:            0.0007949
# There ' s an energy to Y Tu Mamá  También . | Query Exceeded:          no
# There ` ѕ an enеrgy to Y Tu Maｍá También . | Victim Model Queries:    14
#                                             | Succeed:                 yes
#                                             |
# Sample: 42 ====================================================================
# Label: 1 (99.72%) --> 0 (94.50%)            |
#                                             |
# Much of it comes from  the brave ,          |
# Much of it comeѕ froｍ the bravе ,          | Running Time:            0.0007756
#                                             | Query Exceeded:          no
# uninhibited performances by its lead actors | Victim Model Queries:    18
# uninhibited performaոces by its lead actors | Succeed:                 yes
#                                             |
# .                                           |
# .                                           |
#                                             |
# Sample: 43 ====================================================================
# Label: 0 (82.45%) --> 1 (82.81%)            |
#                                             |
# `` 13 Conversations '' holds its goodwill   |
# `` 13 Conversatioոs `' holds its goodwill   | Running Time:            0.0008240
#                                             | Query Exceeded:          no
# close , but is relatively slow to come to   | Victim Model Queries:    22
# close , but is relatively sloԝ 𝚝o ϲome to   | Succeed:                 yes
#                                             |
# the point .                                 |
# the point .                                 |
#                                             |
# Sample: 44 ====================================================================
# Label: 1 (99.29%) --> 0 (67.97%)            |
#                                             |
# `` Auto Focus '' works as an unusual biopic |
# `` Auto Focus '' workѕ as ɑn unusuɑl biopic | Running Time:            0.0008352
#                                             | Query Exceeded:          no
# and document of male swingers in the        | Victim Model Queries:    21
# ɑnd document of male swingers in the        | Succeed:                 yes
#                                             |
# Playboy era                                 |
# Playboy erɑ                                 |
#                                             |
# Sample: 45 ====================================================================
# Label: 1 (88.59%) --> 0 (63.00%)            |
#                                             |
# If Mr . Zhang ' s subject matter is , to    |
# If Mr . Zhɑng ' s subjec𝚝 matter is , to    |
#                                             |
# some degree at least , quintessentially     | Running Time:            0.001725
# some degree at least , quintessentiɑlly     | Query Exceeded:          no
#                                             | Victim Model Queries:    31
# American , his approach to storytelling     | Succeed:                 yes
# American , his approach to story𝚝elling     |
#                                             |
# might be called Iranian .                   |
# might be called Irɑnian .                   |
#                                             |
# Sample: 46 ====================================================================
# Label: 0 (94.29%) --> Failed!               |
#                                             |
# ... a sour little movie at its core ; an    | Running Time:            0.0022717
# exploration of the emptiness that underlay  | Query Exceeded:          no
# the relentless gaiety of the 1920 ' s ...   | Victim Model Queries:    42
# The film ' s ending has a `` What was it    | Succeed:                 no
# all for ? ''                                |
#                                             |
# Sample: 47 ====================================================================
# Label: 1 (99.72%) --> 0 (79.17%)            |
#                                             |
# feeling to it , but like the 1920 ' s , the | Running Time:            0.0013394
# feeling to it , but like the 1920 ' s , the | Query Exceeded:          no
#                                             | Victim Model Queries:    24
# trip there is a great deal of fun .         | Succeed:                 yes
# trip there iѕ ɑ greɑt deal of fuո .         |
#                                             |
# Sample: 48 ====================================================================
# Label: 0 (73.99%) --> 1 (55.62%)            |
#                                             |
# `` Cremaster  3 '' should come with the     | Running Time:            0.0009475
# `` Cremasteⲅ 3 '' should come ԝith the     | Query Exceeded:          no
#                                             | Victim Model Queries:    20
# warning `` For serious film buffs only ! '' | Succeed:                 yes
# warning `` For serious film buffs onlу ! '' |
#                                             |
# Sample: 49 ====================================================================
# Label: 0 (97.45%) --> Failed!               |
#                                             | Running Time:            0.0009840
# Made me unintentionally famous -- as the    | Query Exceeded:          no
# queasy - stomached critic who staggered     | Victim Model Queries:    25
# from the theater and blacked out in the     | Succeed:                 no
# lobby .                                     |
#                                             |
# Sample: 50 ====================================================================
# Label: 1 (99.76%) --> Failed!               |
#                                             | Running Time:            0.0010364
# But believe it or not , it ' s one of the   | Query Exceeded:          no
# most beautiful , evocative works I ' ve     | Victim Model Queries:    24
# seen .                                      | Succeed:                 no
#                                             |
# Sample: 51 ====================================================================
# Label: 1 (99.67%) --> Failed!               |
#                                             | Running Time:            0.0011418
# García Bernal and Talancón are an immensely | Query Exceeded:          no
# appealing couple , and even though their    | Victim Model Queries:    29
# story is predictable , you ' ll want things | Succeed:                 no
# to work out .                               |
#                                             |
# Sample: 52 ====================================================================
# Label: 1 (83.02%) --> 0 (89.73%)            |
#                                             |
# ... a spoof comedy  that carries its share  |
# ... a spoof coｍedy that carries its ѕhare  |
#                                             |
# of laughs -- sometimes a chuckle ,          | Running Time:            0.0012822
# of laսghs -- sometimes a chuckle ,          | Query Exceeded:          no
#                                             | Victim Model Queries:    33
# sometimes a guffaw and , to my great        | Succeed:                 yes
# sometimes a guffaw and , to my grea𝚝        |
#                                             |
# pleasure , the occasional belly laugh .     |
# pleasurе , the occasional belly laugh .     |
#                                             |
# Sample: 53 ====================================================================
# Label: 1 (93.50%) --> 0 (86.41%)            |
#                                             |
# ( City ) reminds us how realistically       |
# ( City ) remiոds uѕ how realistically       |
#                                             |
# nuanced a Robert De Niro performance can be |
# nuanϲed a Robert De Niro performance can be |
#                                             |
# when he is not more lucratively engaged in  |
# ԝhen he is not more lucratively engaged in  | Running Time:            0.0025644
#                                             | Query Exceeded:          no
# the shameless self - caricature of `        | Victim Model Queries:    55
# the shameless self - caricature of `        | Succeed:                 yes
#                                             |
# Analyze This ' ( 1999 ) and ` Analyze That  |
# Analyze This ' ( 1999 ) and ` Analyze That  |
#                                             |
# , ' promised ( or threatened ) for later    |
# , ' promised ( or threatened ) for later    |
#                                             |
# this year .                                 |
# this year .                                 |
#                                             |
# Sample: 54 ====================================================================
# Label: 1 (83.08%) --> 0 (95.62%)            |
#                                             |
# The wanton slipperiness of \* Corpus and    |
# Tհe wanton slipperiness of \* Corpus ɑnd    |
#                                             |
# its amiable jerking and reshaping of        |
# its amiable jerking and reshaping of        | Running Time:            0.0017476
#                                             | Query Exceeded:          no
# physical time and space would make it a     | Victim Model Queries:    38
# ...
# well enough alone and just filmed the opera | Succeed:                 no
# without all these distortions of            |
# perspective .                               |
#                                             |
# Sample: 84 ====================================================================
# Label: 1 (99.69%) --> 0 (81.74%)            |
#                                             |
# The production has been made with an        |
# The production has been made with an        | Running Time:            0.0009029
#                                             | Query Exceeded:          no
# enormous amount of affection , so we        | Victim Model Queries:    24
# enormoսs amount of affectіon , so we        | Succeed:                 yes
#                                             |
# believe these characters love each other .  |
# believe these charactеrs lоve eacհ other .  |
#                                             |
# Sample: 85 ====================================================================
# Label: 1 (99.76%) --> 0 (84.26%)            |
#                                             | Running Time:            0.0005624
# Certainly the performances are worthwhile . | Query Exceeded:          no
# Certainlу thе performancеs are worthwhiⅼe . | Victim Model Queries:    9
#                                             | Succeed:                 yes
#                                             |
# Sample: 86 ====================================================================
# Label: 1 (99.19%) --> 0 (80.40%)            |
#                                             |
# Winds up being both revelatory and          |
# Winds up being both revelatorу anԁ          |
#                                             |
# narcissistic , achieving some honest        |
# narcissistic , achieving some hоnest        |
#                                             |
# insight into relationships that most high - | Running Time:            0.0012431
# inѕight into relationships 𝚝hat most high - | Query Exceeded:          no
#                                             | Victim Model Queries:    36
# concept films candy - coat with pat         | Succeed:                 yes
# concept films candy - coat with pat         |
#                                             |
# storylines , precious circumstances and     |
# storylines , precious circumstances and     |
#                                             |
# beautiful stars .                           |
# beautiful stars .                           |
#                                             |
# Sample: 87 ====================================================================
# Label: 1 (99.75%) --> Failed!               |
#                                             | Running Time:            0.0006075
# Watching these eccentrics is both inspiring | Query Exceeded:          no
# and pure joy .                              | Victim Model Queries:    12
#                                             | Succeed:                 no
#                                             |
# Sample: 88 ====================================================================
# Label: 1 (99.58%) --> 0 (67.37%)            |
#                                             |
# Steven Spielberg brings us another          | Running Time:            0.0005529
# Steven Sрielberg bringѕ uѕ another          | Query Exceeded:          no
#                                             | Victim Model Queries:    9
# masterpiece                                 | Succeed:                 yes
# mas𝚝erpiece                                 |
#                                             |
# Sample: 89 ====================================================================
# Label: 1 (86.16%) --> 0 (92.07%)            |
#                                             |
# Finally , the French - produced `` Read My  |
# Finally , the French - produced `` Read My  | Running Time:            0.0008559
#                                             | Query Exceeded:          no
# Lips '' is a movie that understands         | Victim Model Queries:    24
# Lips '' іs a movіe thɑt underѕtands         | Succeed:                 yes
#                                             |
# characters must come  first .               |
# characters must coｍe first .               |
#                                             |
# Sample: 90 ====================================================================
# Label: 1 (99.77%) --> 0 (58.07%)            |
#                                             |
# Ms . Seigner and Mr . Serrault bring fresh  | Running Time:            0.0007975
# Ms . Seigner and Mr . Serrault Ьring fresհ  | Query Exceeded:          no
#                                             | Victim Model Queries:    19
# , unforced naturalism to their characters . | Succeed:                 yes
# , unforced naturalism to their charactеrs . |
#                                             |
# Sample: 91 ====================================================================
# Label: 1 (99.44%) --> 0 (82.56%)            |
#                                             |
# Allen shows he can outgag any of those      |
# Alⅼen ѕhows hе caո outgɑg any of those      | Running Time:            0.0007312
#                                             | Query Exceeded:          no
# young whippersnappers making moving         | Victim Model Queries:    18
# young whippersnappers making moving         | Succeed:                 yes
#                                             |
# pictures today .                            |
# pictures today .                            |
#                                             |
# Sample: 92 ====================================================================
# Label: 1 (99.80%) --> 0 (86.72%)            |
#                                             |
# A good film  with a solid pedigree both in  |
# A gooԁ filｍ with a sоlid pedigree both in  | Running Time:            0.0008817
#                                             | Query Exceeded:          no
# front of and , more specifically , behind   | Victim Model Queries:    23
# front of aոd , more specifically , behind   | Succeed:                 yes
#                                             |
# the camera .                                |
# the camera .                                |
#                                             |
# Sample: 93 ====================================================================
# Label: 1 (99.52%) --> Failed!               |
#                                             |
# By no means a slam - dunk and sure to       | Running Time:            0.0015886
# ultimately disappoint the action fans who   | Query Exceeded:          no
# will be moved to the edge of their seats by | Victim Model Queries:    45
# the dynamic first act , it still comes off  | Succeed:                 no
# as a touching , transcendent love story .   |
#                                             |
# Sample: 94 ====================================================================
# Label: 1 (99.67%) --> Failed!               |
#                                             | Running Time:            0.0013342
# I encourage young and old alike to go see   | Query Exceeded:          no
# this unique and entertaining twist on the   | Victim Model Queries:    32
# classic whale ' s tale -- you wo n ' t be   | Succeed:                 no
# sorry !                                     |
#                                             |
# Sample: 95 ====================================================================
# Label: 1 (91.84%) --> 0 (93.37%)            |
#                                             |
# A literary detective story is still a       |
# A literary detective story is still a       | Running Time:            0.0011475
#                                             | Query Exceeded:          no
# detective story and aficionados of the      | Victim Model Queries:    24
# detective story and aficionados of the      | Succeed:                 yes
#                                             |
# whodunit wo n ' t be disappointed .         |
# whodunit wo n ` 𝚝 bе disappointеd .         |
#                                             |
# Sample: 96 ====================================================================
# Label: 1 (98.24%) --> 0 (65.58%)            |
#                                             |
# High Crimes steals so freely from other     |
# High Crimes steals so freеly from other     |
#                                             |
# movies and combines  enough disparate types | Running Time:            0.0013971
# movies and coｍbines enough disparate types | Query Exceeded:          no
#                                             | Victim Model Queries:    30
# of films that it ca n ' t help but engage   | Succeed:                 yes
# of films that it ca n ' t hеlp bu𝚝 engage   |
#                                             |
# an audience .                               |
# an aսdience .                               |
#                                             |
# Sample: 97 ====================================================================
# Label: 1 (97.25%) --> 0 (87.07%)            |
#                                             |
# If you ' re a fan of the series you ' ll    | Running Time:            0.0012097
# If you ' re a fan of the series you ' lⅼ    | Query Exceeded:          no
#                                             | Victim Model Queries:    25
# love it and probably want to see it twice . | Succeed:                 yes
# ⅼove іt anԁ probably want to seе it twice . |
#                                             |
# Sample: 98 ====================================================================
# Label: 1 (98.67%) --> 0 (61.04%)            |
#                                             | Running Time:            0.0005028
# I will be .                                 | Query Exceeded:          no
# I ԝill bе .                                 | Victim Model Queries:    7
#                                             | Succeed:                 yes
#                                             |
# Sample: 99 ====================================================================
# Label: 1 (99.13%) --> 0 (96.48%)            |
#                                             |
# It celebrates the group ' s playful spark   |
# It celebra𝚝es the group ' s рlayful spɑrk   |
#                                             |
# of nonconformity , glancing vividly back at | Running Time:            0.0011294
# of nonconformity , glancing vividⅼy back at | Query Exceeded:          no
#                                             | Victim Model Queries:    29
# what Hibiscus grandly called his ` angels   | Succeed:                 yes
# what Hibiscus grandly called his ` angels   |
#                                             |
# of light . '                                |
# of light . `                                |
#                                             |
# Sample: 100 ===================================================================
# Label: 1 (97.54%) --> 0 (97.24%)            |
#                                             |
# The story ... is inspiring  , ironic , and  |
# The stоry ... is inspiⲅing , ironic , and  | Running Time:            0.0011733
#                                             | Query Exceeded:          no
# revelatory of just how ridiculous and money | Victim Model Queries:    27
# revelatory o𝚏 just hоw ridiculous and money | Succeed:                 yes
#                                             |
# - oriented the record industry really is .  |
# - oriented the record industry really is .  |
#                                             |
# +========================================+
# |                Summary                 |
# +========================================+
# | Total Attacked Instances:  | 100       |
# | Successful Instances:      | 74        |
# | Attack Success Rate:       | 0.74      |
# | Avg. Running Time:         | 0.0011038 |
# | Total Query Exceeded:      | 0         |
# | Avg. Victim Model Queries: | 25.47     |
# +========================================+

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import OpenAttack as oa
import numpy as np
import datasets
import sentencepiece as spm


def dataset_mapping(x):
    return {
        "x": x["sentence"],
        #"x": x["text"],
        "y": 1 if x["label"] > 0.5 else 0,
        # "y": x["label"],
    }

def main():
    # 从 datasets 库中加载 IMDB 数据集的前 2000 个样本
    imdb_train = datasets.load_dataset("sst", split="train[:100]").map(function=dataset_mapping)

    victim = oa.DataManager.loadVictim("BERT.SST").to("cuda:0")
    #victim = oa.DataManager.loadVictim("ALBERT.IMDB").to("cuda:0")


    # 选择 Deepwordbug 作为攻击者并使用默认参数初始化
    attacker = oa.attackers.BERTAttacker() # 修改此行
    #attacker = oa.attackers.TextBuggerAttacker()

    # 准备进行攻击
    """attack_eval = oa.AttackEval(attacker, victim, metrics = [
        # oa.metric.SemanticSimilarity(),
        # oa.metric.GrammaticalErrors(),
        # OpenAttack.metric.Fluency()
        # OpenAttack.metric.EditDistance(),
        oa.metric.ModificationRate(),
    ])"""
    attack_eval = oa.AttackEval(attacker, victim)

    # 发起攻击并打印攻击结果
    # attack_eval.eval(imdb_train, visualize=True,num_workers=2)
    attack_eval.eval(imdb_train, visualize=True)

if __name__ == "__main__":
    main()
# Out:
# WARNING:datasets.builder:No config specified, defaulting to: sst/default
# WARNING:datasets.builder:Found cached dataset sst (/root/.cache/huggingface/datasets/sst/default/1.0.0/b8a7889ef01c5d3ae8c379b84cc4080f8aad3ac2bc538701cbe0ac6416fb76ff)
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/sst/default/1.0.0/b8a7889ef01c5d3ae8c379b84cc4080f8aad3ac2bc538701cbe0ac6416fb76ff/cache-ee1d1c8ae6622e4f.arrow
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Sample: 1 =====================================================================
# Label: 1 (98.17%) --> 0 (51.54%)            |
#                                             |
# The Rock is destined to be the 21st Century |
# the rock is looking  to be the 21st century |
#                                             |
# ' s new `` Conan '' and that he ' s going   |
# ' s new `` conan '' and that he , m got     | Running Time:            0.18682
#                                             | Query Exceeded:          no
# to make a splash even greater than Arnold   | Victim Model Queries:    108
# to make a splash even less    than arnold   | Succeed:                 yes
#                                             |
# Schwarzenegger , Jean - Claud Van Damme or  |
# schwarzenegger , jean - claud van damme or  |
#                                             |
# Steven Segal .                              |
# steven segal .                              |
#                                             |
# Sample: 2 =====================================================================
# Label: 1 (99.30%) --> 0 (61.67%)            |
#                                             |
# The     gorgeously elaborate continuation   |
# the ... ly         elaborate continuation   |
#                                             |
# of `` The Lord of the Rings '' trilogy is   |
# of `` the lord of the rings '' trilogy is   |
#                                             |
# so huge that a column of words can not      | Running Time:            0.030519
# so huge that a column of words can not      | Query Exceeded:          no
#                                             | Victim Model Queries:    41
# adequately describe co - writer \/ director | Succeed:                 yes
# adequately describe co - writer \/ director |
#                                             |
# Peter Jackson ' s expanded vision of J . R  |
# peter jackson ' s expanded vision of j . r  |
#                                             |
# . R . Tolkien ' s Middle - earth .          |
# . r . tolkien ' s middle - earth .          |
#                                             |
# Sample: 3 =====================================================================
# Label: 1 (87.19%) --> 0 (98.26%)            |
#                                             |
# Singer \/ composer Bryan Adams contributes  |
# singer \/ composer bryan adams contributes  |
#                                             |
# a slew of songs -- a few potential hits , a |
# a slew of songs -- a few potential hits , a | Running Time:            0.01944
#                                             | Query Exceeded:          no
# few more simply intrusive to the story --   | Victim Model Queries:    44
# few more simply intrusive to the story --   | Succeed:                 yes
#                                             |
# but the whole package certainly captures    |
# but the whole package certainly lacks       |
#                                             |
# the intended , er , spirit of the piece .   |
# the intended , er , spirit of the piece .   |
#                                             |
# Sample: 4 =====================================================================
# Label: 0 (84.86%) --> 1 (60.08%)            |
#                                             |
# You ' d think by now America would have had |
# you ' d think by now america would have had | Running Time:            0.035722
#                                             | Query Exceeded:          no
# enough of plucky  British eccentrics with   | Victim Model Queries:    23
# enough of plwding british eccentrics with   | Succeed:                 yes
#                                             |
# hearts of gold .                            |
# hearts of gold .                            |
#                                             |
# Sample: 5 =====================================================================
# Label: 1 (99.63%) --> 0 (83.54%)            |
#                                             | Running Time:            0.017735
# Yet the act is still charming here .        | Query Exceeded:          no
# yet the act is still harmless here .        | Victim Model Queries:    17
#                                             | Succeed:                 yes
#                                             |
# Sample: 6 =====================================================================
# Label: 1 (99.73%) --> 0 (67.27%)            |
#                                             |
# Whether or not you ' re enlightened by any  |
# whether or not you ' re enlightened by any  |
#                                             |
# of Derrida ' s lectures on `` the other ''  |
# of derrida ' s lectures on `` the other ''  | Running Time:            0.091692
#                                             | Query Exceeded:          no
# and `` the self , '' Derrida is an          | Victim Model Queries:    98
# and `` the self , '' derrida is an          | Succeed:                 yes
#                                             |
# undeniably  fascinating and playful         |
# undesiously enigma      and intellectual    |
#                                             |
# fellow .                                    |
# fellow .                                    |
#                                             |
# Sample: 7 =====================================================================
# Label: 1 (99.27%) --> 0 (73.53%)            |
#                                             |
# Just the labour involved in creating the    |
# just the labour involved in creating the    |
#                                             |
# layered richness of the imagery in this     | Running Time:            0.036399
# layered richness of the imagery in this     | Query Exceeded:          no
#                                             | Victim Model Queries:    49
# chiaroscuro of madness and light is         | Succeed:                 yes
# chiaroscuro of madness and light is         |
#                                             |
# astonishing .                               |
# enigma      .                               |
#                                             |
# Sample: 8 =====================================================================
# Label: 1 (99.57%) --> Failed!               |
#                                             | Running Time:            0.11847
# Part of the charm of Satin Rouge is that it | Query Exceeded:          no
# avoids the obvious with humour and          | Victim Model Queries:    134
# lightness .                                 | Succeed:                 no
#                                             |
# Sample: 9 =====================================================================
# Label: 1 (91.95%) --> 0 (63.42%)            |
#                                             |
# a screenplay more ingeniously constructed   | Running Time:            0.031294
# a screenplay more ingeriatly  constructed   | Query Exceeded:          no
#                                             | Victim Model Queries:    12
# than `` Memento ''                          | Succeed:                 yes
# than `` memento ''                          |
#                                             |
# Sample: 10 ====================================================================
# Label: 1 (96.40%) --> 0 (74.74%)            |
#                                             | Running Time:            0.026568
# `` Extreme Ops '' exceeds  expectations .   | Query Exceeded:          no
# `` extreme ops '' requires expectations .   | Victim Model Queries:    17
#                                             | Succeed:                 yes
#                                             |
# Sample: 11 ====================================================================
# Label: 1 (99.74%) --> Failed!               |
#                                             | Running Time:            0.15933
# Good fun , good action , good acting , good | Query Exceeded:          no
# dialogue , good pace , good cinematography  | Victim Model Queries:    155
# .                                           | Succeed:                 no
#                                             |
# Sample: 12 ====================================================================
# Label: 1 (58.80%) --> 0 (69.11%)            |
#                                             |
# You Should Pay Nine Bucks for This :        |
# you should pay nine bucks for this :        |
#                                             |
# Because you can hear about suffering Afghan | Running Time:            0.01701
# because you can hear about suffering afghan | Query Exceeded:          no
#                                             | Victim Model Queries:    27
# refugees on the news and still be           | Succeed:                 yes
# refugees on the news and still be           |
#                                             |
# unaffected .                                |
# affected   .                                |
#                                             |
# Sample: 13 ====================================================================
# Label: 1 (98.15%) --> 0 (54.90%)            |
#                                             | Running Time:            0.016052
# Dramas like this make it human    .         | Query Exceeded:          no
# dramas like this make it ordinary .         | Victim Model Queries:    12
#                                             | Succeed:                 yes
#                                             |
# Sample: 14 ====================================================================
# Label: 0 (95.55%) --> 1 (52.53%)            |
#                                             |
# A thunderous ride at first , quiet cadences |
# a thunderous ride at first , quiet cadences |
#                                             |
# of pure finesse are few and far between ;   | Running Time:            0.052961
# of pure finesse are few and far between ;   | Query Exceeded:          no
#                                             | Victim Model Queries:    53
# their shortage         dilutes the potency  | Succeed:                 yes
# their shortage dilnate is      the potency  |
#                                             |
# of otherwise respectable action .           |
# of otherwise restrained  action .           |
#                                             |
# Sample: 15 ====================================================================
# Label: 1 (99.80%) --> 0 (59.74%)            |
#                                             |
# Still , this flick is fun , and host   to   | Running Time:            0.085171
# still , this flick is ... , and listen to   | Query Exceeded:          no
#                                             | Victim Model Queries:    111
# some truly       excellent sequences .      | Succeed:                 yes
# some essentially action    sequences .      |
#                                             |
# Sample: 16 ====================================================================
# Label: 1 (99.79%) --> 0 (51.23%)            |
#                                             |
# Australian actor \/ director John Polson    |
# australian actor \/ director john polson    |
#                                             |
# and award - winning English cinematographer |
# and award - winning english cinematographer | Running Time:            0.12276
#                                             | Query Exceeded:          no
# Giles Nuttgens make a terrific effort at    | Victim Model Queries:    134
# giles nuttgens made a ]        effort at    | Succeed:                 yes
#                                             |
# disguising the obvious with energy    and   |
# disguising the basic   with animation and   |
#                                             |
# innovation .                                |
# innovation .                                |
#                                             |
# Sample: 17 ====================================================================
# Label: 1 (97.57%) --> 0 (72.74%)            |
#                                             |
# You walk out of The Good Girl with mixed    |
# you walk out of the good girl with mixed    |
#                                             |
# emotions -- disapproval of Justine combined | Running Time:            0.025937
# emotions -- disapproval of justine combined | Query Exceeded:          no
#                                             | Victim Model Queries:    37
# with a tinge of understanding for her       | Succeed:                 yes
# with a tinge of regret        for her       |
#                                             |
# actions .                                   |
# actions .                                   |
#                                             |
# Sample: 18 ====================================================================
# Label: 0 (96.38%) --> Failed!               |
#                                             | Running Time:            0.15926
# Post 9 \/ 11 the philosophical message of   | Query Exceeded:          no
# `` Personal Freedom First '' might not be   | Victim Model Queries:    117
# as palatable as intended .                  | Succeed:                 no
#                                             |
# Sample: 19 ====================================================================
# Label: 1 (99.85%) --> 0 (57.66%)            |
#                                             | Running Time:            0.026576
# Absorbing character study by André Turpin . | Query Exceeded:          no
# (         ,         study by andré turpin . | Victim Model Queries:    26
#                                             | Succeed:                 yes
#                                             |
# Sample: 20 ====================================================================
# Label: 1 (96.35%) --> 0 (56.97%)            |
#                                             |
# If you love    reading and \/ or poetry ,   | Running Time:            0.042544
# if you dislike reading and \/ or poetry ,   | Query Exceeded:          no
#                                             | Victim Model Queries:    54
# then by all means check it out .            | Succeed:                 yes
# then by all means look  it out .            |
#                                             |
# Sample: 21 ====================================================================
# Label: 1 (99.57%) --> 0 (86.18%)            |
#                                             | Running Time:            0.022692
# You ' ll probably love it .                 | Query Exceeded:          no
# you ' ll probably hate it .                 | Victim Model Queries:    22
#                                             | Succeed:                 yes
#                                             |
# Sample: 22 ====================================================================
# Label: 1 (55.90%) --> 0 (90.72%)            |
#                                             |
# `` Frailty '' has been written so well ,    | Running Time:            0.016142
# `` frailty '' has been written so far  ,    | Query Exceeded:          no
#                                             | Victim Model Queries:    20
# that even a simple `` Goddammit ! ''        | Succeed:                 yes
# that even a simple `` goddammit ! ''        |
#                                             |
# Sample: 23 ====================================================================
# Label: 0 (87.29%) --> 1 (50.85%)            |
#                                             |
# near the end takes on a whole other         | Running Time:            0.038327
# "    the end takes on a whole other         | Query Exceeded:          no
#                                             | Victim Model Queries:    48
# meaning   .                                 | Succeed:                 yes
# dimension .                                 |
#                                             |
# Sample: 24 ====================================================================
# Label: 1 (99.78%) --> 0 (82.48%)            |
#                                             |
# Grenier is terrific , bringing an unforced  |
# grenier is new      , putting  an unieged   |
#                                             |
# , rapid - fire delivery to Toback ' s       | Running Time:            0.079839
# , rapid - fire delivery to toback ' s       | Query Exceeded:          no
#                                             | Victim Model Queries:    77
# Heidegger - and Nietzsche - referencing     | Succeed:                 yes
# heidegger - and nietzsche - referencing     |
#                                             |
# dialogue .                                  |
# dialogue .                                  |
#                                             |
# Sample: 25 ====================================================================
# Label: 0 (53.24%) --> 1 (57.45%)            |
#                                             |
# The Sundance Film Festival has become so    |
# the sundance film festival has become so    |
#                                             |
# buzz - obsessed that fans and producers     | Running Time:            0.017038
# buzz - obsessed that fans and filmmakers    | Query Exceeded:          no
#                                             | Victim Model Queries:    28
# descend upon Utah each January to ferret    | Succeed:                 yes
# descend upon utah each january to ferret    |
#                                             |
# out The Next Great Thing .                  |
# out the next great thing .                  |
#                                             |
# Sample: 26 ====================================================================
# Label: 0 (56.22%) --> 1 (69.36%)            |
#                                             |
# ` Tadpole ' was one of the films so         |
# ` tadpole ' was one of the films so         | Running Time:            0.016407
#                                             | Query Exceeded:          no
# declared this year , but it ' s really more | Victim Model Queries:    28
# declared this year , but it ' s really more | Succeed:                 yes
#                                             |
# of The Next Pretty Good Thing  .            |
# of the next pretty good things .            |
#                                             |
# Sample: 27 ====================================================================
# Label: 1 (99.79%) --> 0 (98.17%)            |
#                                             | Running Time:            0.032598
# The actors are fantastic .                  | Query Exceeded:          no
# the actors are terrible  .                  | Victim Model Queries:    41
#                                             | Succeed:                 yes
#                                             |
# Sample: 28 ====================================================================
# Label: 1 (99.70%) --> 0 (85.43%)            |
#                                             |
# They are what makes it worth   the trip to  | Running Time:            0.020528
# they are what makes it costing the trip to  | Query Exceeded:          no
#                                             | Victim Model Queries:    23
# the theatre .                               | Succeed:                 yes
# the theatre .                               |
#                                             |
# Sample: 29 ====================================================================
# Label: 1 (96.33%) --> 0 (52.04%)            |
#                                             |
# ( Taymor ) utilizes the idea of making      |
# ( taymor , utilizes the idea of making      |
#                                             |
# Kahlo ' s art a living , breathing part of  | Running Time:            0.057601
# kahlo ' s art a living , breathing part of  | Query Exceeded:          no
#                                             | Victim Model Queries:    56
# the movie , often        catapulting the    | Succeed:                 yes
# the movie , often transa moldning    the    |
#                                             |
# artist into her own work .                  |
# artist into her own work .                  |
#                                             |
# Sample: 30 ====================================================================
# Label: 0 (93.75%) --> 1 (88.64%)            |
#                                             | Running Time:            0.041221
# This is n ' t a new  idea .                 | Query Exceeded:          no
# this is n t n a good idea .                 | Victim Model Queries:    28
#                                             | Succeed:                 yes
#                                             |
# Sample: 31 ====================================================================
# Label: 1 (95.38%) --> 0 (71.57%)            |
#                                             |
# It ' s been done before but never so        | Running Time:            0.047734
# it ' s been done before but never so        | Query Exceeded:          no
#                                             | Victim Model Queries:    48
# vividly or with so   much passion .         | Succeed:                 yes
# vividly or with very much since   .         |
#                                             |
# Sample: 32 ====================================================================
# Label: 1 (99.77%) --> 0 (75.21%)            |
#                                             |
# ( `` Take Care of My Cat '' ) is an         |
# ( `` take care of my cat '' ) is an         |
#                                             |
# honestly nice little film that takes us on  |
# ...      very little film that takes us on  | Running Time:            0.085626
#                                             | Query Exceeded:          no
# an examination of young adult life in urban | Victim Model Queries:    79
# an examination of young adult life in urban | Succeed:                 yes
#                                             |
# South Korea through the hearts and minds of |
# south korea through the hearts and minds of |
#                                             |
# the five principals .                       |
# the five principals .                       |
#                                             |
# Sample: 33 ====================================================================
# Label: 1 (92.60%) --> 0 (77.53%)            |
#                                             |
# It ' s not life - affirming -- its vulgar   | Running Time:            0.030922
# it ' s not life - affirming -- its vulgar   | Query Exceeded:          no
#                                             | Victim Model Queries:    21
# and mean , but I liked  it .                | Succeed:                 yes
# and mean , but i played it .                |
#                                             |
# Sample: 34 ====================================================================
# Label: 1 (96.39%) --> 0 (77.48%)            |
#                                             |
# What `` Empire '' lacks in depth it makes   | Running Time:            0.037528
# what `` empire '' lacks in depth it knows   | Query Exceeded:          no
#                                             | Victim Model Queries:    23
# up for with its heart .                     | Succeed:                 yes
# up for with its heart .                     |
#                                             |
# Sample: 35 ====================================================================
# Label: 1 (99.63%) --> 0 (96.57%)            |
#                                             |
# Light , silly , photographed with colour    | Running Time:            0.016939
# light , silly , photographed with colour    | Query Exceeded:          no
#                                             | Victim Model Queries:    20
# and depth , and rather a good time .        | Succeed:                 yes
# and depth , and rather a bad  time .        |
#                                             |
# Sample: 36 ====================================================================
# Label: 1 (97.26%) --> 0 (51.25%)            |
#                                             |
# But tongue - in - cheek preposterousness    |
# but tongue - in - cheek preposterousness    |
#                                             |
# has always been part of For the most part   |
# has always been part of for the most part   | Running Time:            0.035826
#                                             | Query Exceeded:          no
# Wilde ' s droll whimsy helps `` Being       | Victim Model Queries:    50
# wilde ' s droll whimsy does  `` being       | Succeed:                 yes
#                                             |
# Earnest '' overcome its weaknesses and      |
# earnest '' overcame its weaknesses and      |
#                                             |
# Parker ' s creative interference ...        |
# parker ' s creative interference ...        |
#                                             |
# Sample: 37 ====================================================================
# Label: 1 (99.59%) --> 0 (76.44%)            |
#                                             |
# Much of the movie ' s charm    lies in the  | Running Time:            0.040897
# much of the movie ' s weakness lies in the  | Query Exceeded:          no
#                                             | Victim Model Queries:    53
# utter cuteness of Stuart and Margolo .      | Succeed:                 yes
# utter cuteness of stuart and margolo .      |
#                                             |
# Sample: 38 ====================================================================
# Label: 1 (99.52%) --> 0 (51.90%)            |
#                                             |
# Their computer - animated faces are very    | Running Time:            0.017935
# their computer - animated faces are very    | Query Exceeded:          no
#                                             | Victim Model Queries:    14
# expressive  .                               | Succeed:                 yes
# expressions .                               |
#                                             |
# Sample: 39 ====================================================================
# Label: 0 (91.92%) --> 1 (50.50%)            |
#                                             |
# The path  Ice Age follows most closely ,    |
# the paths ice age leads   most closely ,    |
#                                             |
# though ,     is the one established by      |
# though elite is the one established by      | Running Time:            0.061649
#                                             | Query Exceeded:          no
# Warner Bros . giant Chuck Jones , who died  | Victim Model Queries:    78
# warner bros . giant chuck jones , who died  | Succeed:                 yes
#                                             |
# a matter of weeks before the movie ' s      |
# a matter of weeks before the movie ' s      |
#                                             |
# release .                                   |
# release .                                   |
#                                             |
# Sample: 40 ====================================================================
# Label: 1 (98.54%) --> 0 (77.53%)            |
#                                             |
# ... spiced with humor ( ' I speak fluent    |
# ... spiced with gag   ( ' i speak fluent    |
#                                             |
# flatula , ' advises Denlopp after a rather  |
# flatula , ' advises denlopp after a rather  |
#                                             |
# , er , bubbly exchange with an alien        |
# , er , bubbly exchange with an alien        | Running Time:            0.064437
#                                             | Query Exceeded:          no
# deckhand ) and witty   updatings ( Silver ' | Victim Model Queries:    87
# deckhand ) and various updatings ( silver ' | Succeed:                 yes
#                                             |
# s parrot has been replaced with Morph , a   |
# s parrot has been replaced with morph , a   |
#                                             |
# cute alien creature who mimics everyone and |
# cute alien creature who mimics everyone and |
#                                             |
# everything around )                         |
# everything around )                         |
#                                             |
# Sample: 41 ====================================================================
# Label: 1 (99.46%) --> 0 (51.35%)            |
#                                             | Running Time:            0.0248
# There ' s an energy to Y Tu Mamá También .  | Query Exceeded:          no
# there ' s an effort to y tu mamá también .  | Victim Model Queries:    26
#                                             | Succeed:                 yes
#                                             |
# Sample: 42 ====================================================================
# Label: 1 (99.72%) --> 0 (55.48%)            |
#                                             |
# Much of it comes from the brave ,           |
# much of it comes from the hero  ,           | Running Time:            0.031482
#                                             | Query Exceeded:          no
# uninhibited performances by its lead actors | Victim Model Queries:    38
# uninhibited performances by its lead actors | Succeed:                 yes
#                                             |
# .                                           |
# .                                           |
#                                             |
# Sample: 43 ====================================================================
# Label: 0 (82.45%) --> 1 (82.95%)            |
#                                             |
# `` 13 Conversations '' holds its goodwill   |
# `` 13 conversations '' holds its goodwill   | Running Time:            0.02395
#                                             | Query Exceeded:          no
# close , but is relatively slow  to come to  | Victim Model Queries:    24
# close , but is relatively quick to come to  | Succeed:                 yes
#                                             |
# the point .                                 |
# the point .                                 |
#                                             |
# Sample: 44 ====================================================================
# Label: 1 (99.29%) --> 0 (84.02%)            |
#                                             |
# `` Auto Focus '' works  as an unusual       |
# `` auto focus '' serves as an bizarre       | Running Time:            0.059694
#                                             | Query Exceeded:          no
# biopic and document of male swingers in the | Victim Model Queries:    54
# biopic and document of male swingers in the | Succeed:                 yes
#                                             |
# Playboy era                                 |
# playboy era                                 |
#                                             |
# Sample: 45 ====================================================================
# Label: 1 (88.59%) --> 0 (61.83%)            |
#                                             |
# If Mr . Zhang ' s subject matter is , to    |
# if mr . zhang ' s subject matter is , to    |
#                                             |
# some degree at least ,                      | Running Time:            0.077553
# some degree at least , sntes - not          | Query Exceeded:          no
#                                             | Victim Model Queries:    30
# quintessentially American , his approach to | Succeed:                 yes
# american         american , his approach to |
#                                             |
# storytelling might be called Iranian .      |
# storytelling might be called iranian .      |
#                                             |
# Sample: 46 ====================================================================
# Label: 0 (94.29%) --> 1 (61.13%)            |
#                                             |
# ... a sour   little movie at its core ; an  |
# ... a little little movie at its core ; an  |
#                                             |
# exploration of the emptiness that underlay  |
# exploration of the emptiness that underlay  | Running Time:            0.048131
#                                             | Query Exceeded:          no
# the relentless gaiety of the 1920 ' s ...   | Victim Model Queries:    49
# the relentless gaiety of the 1920 ' s ...   | Succeed:                 yes
#                                             |
# The film ' s ending has a `` What was it    |
# the film ' s ending has a `` what was it    |
#                                             |
# all for ? ''                                |
# all for ? ''                                |
#                                             |
# Sample: 47 ====================================================================
# Label: 1 (99.72%) --> 0 (94.32%)            |
#                                             |
# feeling to it , but like the 1920 ' s , the | Running Time:            0.037722
# feeling to it , but like the 1920 ' s , the | Query Exceeded:          no
#                                             | Victim Model Queries:    37
# trip there is a great deal of fun  .        | Succeed:                 yes
# trip there is a great deal of drag .        |
#                                             |
# Sample: 48 ====================================================================
# Label: 0 (73.99%) --> 1 (54.40%)            |
#                                             |
# `` Cremaster 3 '' should come with the      |
# `` cremaster 3 '' will   come with the      | Running Time:            0.054315
#                                             | Query Exceeded:          no
# warning `` For serious film buffs only      | Victim Model Queries:    46
# warning `` for serious film buffs only      | Succeed:                 yes
#                                             |
# !        ''                                 |
# tomorrow ''                                 |
#                                             |
# ...
# believe these characters miss each other .  |
#                                             |
# Sample: 85 ====================================================================
# Label: 1 (99.76%) --> Failed!               |
#                                             | Running Time:            0.070317
#                                             | Query Exceeded:          no
# Certainly the performances are worthwhile . | Victim Model Queries:    54
#                                             | Succeed:                 no
#                                             |
# Sample: 86 ====================================================================
# Label: 1 (99.19%) --> 0 (57.42%)            |
#                                             |
# Winds up being both revelatory and          |
# winds up being both revelatory and          |
#                                             |
# narcissistic , achieving some honest        |
# narcissistic , taking    some innocent      |
#                                             |
# insight into relationships that most high - | Running Time:            0.11853
# .       into relationships that most high - | Query Exceeded:          no
#                                             | Victim Model Queries:    97
# concept films candy - coat with pat         | Succeed:                 yes
# concept films candy - coat with pat         |
#                                             |
# storylines , precious circumstances and     |
# storylines , precious circumstances and     |
#                                             |
# beautiful stars .                           |
# beautiful stars .                           |
#                                             |
# Sample: 87 ====================================================================
# Label: 1 (99.75%) --> Failed!               |
#                                             | Running Time:            0.076134
# Watching these eccentrics is both inspiring | Query Exceeded:          no
# and pure joy .                              | Victim Model Queries:    86
#                                             | Succeed:                 no
#                                             |
# Sample: 88 ====================================================================
# Label: 1 (99.58%) --> 0 (83.53%)            |
#                                             |
# Steven Spielberg brings  us   another       | Running Time:            0.040767
# steven spielberg imports like another       | Query Exceeded:          no
#                                             | Victim Model Queries:    45
# masterpiece                                 | Succeed:                 yes
# masterpiece                                 |
#                                             |
# Sample: 89 ====================================================================
# Label: 1 (86.16%) --> 0 (89.02%)            |
#                                             |
# Finally , the French - produced `` Read My  |
# finally , the french - produced `` read my  | Running Time:            0.016504
#                                             | Query Exceeded:          no
# Lips '' is a movie that understands         | Victim Model Queries:    22
# lips '' is a movie that believes            | Succeed:                 yes
#                                             |
# characters must come first .                |
# characters must come first .                |
#                                             |
# Sample: 90 ====================================================================
# Label: 1 (99.77%) --> Failed!               |
#                                             | Running Time:            0.074719
# Ms . Seigner and Mr . Serrault bring fresh  | Query Exceeded:          no
# , unforced naturalism to their characters . | Victim Model Queries:    100
#                                             | Succeed:                 no
#                                             |
# Sample: 91 ====================================================================
# Label: 1 (99.44%) --> 0 (54.26%)            |
#                                             |
# Allen shows he can outgag any of those      |
# )     jokes he can outgag any of those      | Running Time:            0.040991
#                                             | Query Exceeded:          no
# young whippersnappers making moving         | Victim Model Queries:    53
# young whippersnappers making moving         | Succeed:                 yes
#                                             |
# pictures today .                            |
# pictures today .                            |
#                                             |
# Sample: 92 ====================================================================
# Label: 1 (99.80%) --> 0 (95.58%)            |
#                                             |
# A good film with a solid pedigree both in   |
# a bad  film with a solid pedigree both in   | Running Time:            0.041141
#                                             | Query Exceeded:          no
# front of and , more specifically , behind   | Victim Model Queries:    55
# front of and , more specifically , behind   | Succeed:                 yes
#                                             |
# the camera .                                |
# the camera .                                |
#                                             |
# Sample: 93 ====================================================================
# Label: 1 (99.52%) --> 0 (73.62%)            |
#                                             |
# By no means a slam - dunk and sure to       |
# by no means a slam - dunk and sure to       |
#                                             |
# ultimately disappoint the action fans who   |
# ultimately disappoint the action fans who   | Running Time:            0.12945
#                                             | Query Exceeded:          no
# will be moved to the edge of their seats by | Victim Model Queries:    112
# will be moved to the edge of their seats by | Succeed:                 yes
#                                             |
# the dynamic first act , it still comes off  |
# the dynamic first act , it still seems off  |
#                                             |
# as a touching , transcendent love story .   |
# as a simple   - transcendent love story .   |
#                                             |
# Sample: 94 ====================================================================
# Label: 1 (99.67%) --> 0 (71.76%)            |
#                                             |
# I encourage  young and old alike to go see  |
# i discourage young and old alike to go see  |
#                                             |
# this unique and entertaining twist on the   | Running Time:            0.1231
# this unique and -            twist on the   | Query Exceeded:          no
#                                             | Victim Model Queries:    99
# classic whale ' s tale -- you wo n ' t  be  | Succeed:                 yes
# classic whale ' s tale -- you wo n . ll be  |
#                                             |
# sorry !                                     |
# sorry !                                     |
#                                             |
# Sample: 95 ====================================================================
# Label: 1 (91.84%) --> 0 (94.65%)            |
#                                             |
# A literary detective story is still a       |
# a literary detective story is still a       | Running Time:            0.033925
#                                             | Query Exceeded:          no
# detective story and aficionados of the      | Victim Model Queries:    22
# detective story and aficionados of the      | Succeed:                 yes
#                                             |
# whodunit wo n ' t be disappointed .         |
# whodunit wo n ' s be disappointed .         |
#                                             |
# Sample: 96 ====================================================================
# Label: 1 (98.24%) --> 0 (51.11%)            |
#                                             |
# High Crimes steals so freely from other     |
# high crimes sounds so direct from other     |
#                                             |
# movies and combines enough disparate types  | Running Time:            0.067115
# movies and combines enough disparate types  | Query Exceeded:          no
#                                             | Victim Model Queries:    88
# of films that it ca n ' t help but engage   | Succeed:                 yes
# of films that it ca n ' t help but engage   |
#                                             |
# an audience .                               |
# an .        .                               |
#                                             |
# Sample: 97 ====================================================================
# Label: 1 (97.25%) --> 0 (76.84%)            |
#                                             |
# If you ' re a fan of the series you ' ll    | Running Time:            0.020653
# if you ' re a fan of the series you ' ll    | Query Exceeded:          no
#                                             | Victim Model Queries:    31
# love it and probably want to see it twice . | Succeed:                 yes
# miss it and probably want to see it twice . |
#                                             |
# Sample: 98 ====================================================================
# Label: 1 (98.67%) --> Failed!               |
#                                             | Running Time:            0.021
#                                             | Query Exceeded:          no
# I will be .                                 | Victim Model Queries:    19
#                                             | Succeed:                 no
#                                             |
# Sample: 99 ====================================================================
# Label: 1 (99.13%) --> 0 (60.01%)            |
#                                             |
# It celebrates the group ' s playful         |
# it ,          the group ' s collective      |
#                                             |
# spark of nonconformity , glancing vividly   | Running Time:            0.0821
# spark of nonconformity , glancing brights   | Query Exceeded:          no
#                                             | Victim Model Queries:    82
# back at what Hibiscus grandly called his `  | Succeed:                 yes
# back at what hibiscus grandly called his `  |
#                                             |
# angels of light . '                         |
# angels of light . '                         |
#                                             |
# Sample: 100 ===================================================================
# Label: 1 (97.54%) --> 0 (73.88%)            |
#                                             |
# The story ... is inspiring , ironic , and   |
# the story ... is oblique   , ironic , and   | Running Time:            0.025503
#                                             | Query Exceeded:          no
# revelatory of just how ridiculous and money | Victim Model Queries:    37
# revelatory of just how ridiculous and money | Succeed:                 yes
#                                             |
# - oriented the record industry really is .  |
# - oriented the record industry really is .  |
#                                             |
# +=======================================+
# |                Summary                |
# +=======================================+
# | Total Attacked Instances:  | 100      |
# | Successful Instances:      | 91       |
# | Attack Success Rate:       | 0.91     |
# | Avg. Running Time:         | 0.056196 |
# | Total Query Exceeded:      | 0        |
# | Avg. Victim Model Queries: | 57.33    |
# +=======================================+
